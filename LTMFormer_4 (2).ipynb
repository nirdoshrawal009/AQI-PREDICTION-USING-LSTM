# %% [markdown]
# #Data preprocessed

# %%
import os
import numpy as np
import pandas as pd
import time
import functools

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, BatchSampler
from torch.utils.data import Dataset
from torch.utils.data.sampler import BatchSampler
import torch.optim as optim
from sklearn.model_selection import KFold
import torch.utils.data as data_utils


from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_log_error as msle
from sklearn.model_selection import StratifiedKFold, KFold
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
df_sub2 = pd.read_csv('/content/sample_submission.csv')

# %%
df2 = pd.read_csv('/content/file_name.csv')
#df2=df2.drop('Unnamed: 8',axis=1)
df2.head()

# %%
df_test2 = pd.read_csv('/content/test_public.csv')

# %%
df_test2.head()

# %%
SEQ_LEN = 168

# %%
test_list1 = df_test2.groupby('train or test')['time'].first().reset_index()
test_list1 = test_list1['time'].values.tolist()
test_list2 = df_test2.groupby('train or test')['time'].last().reset_index()
test_list2 = test_list2['time'].values.tolist()
test_list1.extend(test_list2)
test_list1.sort()
test_list1

# %%
COLUMNS_Y = (["PM2.5","PM10",	"SO2", "NO2",	"CO",	"O3"])
COLUMNS_X = COLUMNS_Y + ['day', 'hour', 'dayofweek']
COLUMNS_X, COLUMNS_Y

# %%
COLUMNS_Y = (["PM2.5","PM10",	"SO2", "NO2",	"CO",	"O3"])
COLUMNS_X = COLUMNS_Y + ['day', 'hour', 'dayofweek']
COLUMNS_X, COLUMNS_Y

# %%
def add_time_feat(data):
    data['time'] = pd.to_datetime(data['time'])
    data['day'] = data['time'].dt.day
    data['hour'] = data['time'].dt.hour
    data['minute'] = data['time'].dt.minute
    data['dayofweek'] = data['time'].dt.dayofweek
    return data.sort_values('time').reset_index(drop=True)

def add_other_feat(data, columns):
    data['flow_sum'] = data[columns].sum()
    data['flow_median'] = data[columns].median()
    data['flow_mean'] = data[columns].mean()
    return data

# %%
df2 = add_time_feat(df2)

# %%
df2.head()

# %%
df2.shape

# %%
class Trans:
    def __init__(self, data, name):
        self.min = max(0, np.percentile(data, 1))
        self.max = np.percentile(data, 99)
        self.base = self.max-self.min

    def transform(self, data, scale=True):
        _data = np.clip(data, self.min, self.max)
        if not scale:
            return _data
        return (_data-self.min)/self.base

class TransUtil:
    def __init__(self, data, exclude_cols=None):
        self.columns = data.columns
        self.exclude_cols = exclude_cols
        self.trans = {}
        for c in self.columns:
            if data[c].dtype not in [int, float]:
                print('column "{}" not init trans...'.format(c))
                continue

            if exclude_cols is None or (exclude_cols is not None and c not in exclude_cols):
                print('init trans column...', c)
                self.trans[c] = Trans(data[c].fillna(method='backfill').fillna(method='ffill'), c)

    def transform(self, data, col_name, scale=True):
        if self.exclude_cols is not None and col_name in self.exclude_cols:
            return data

        for t in self.trans:
            if t.startswith(col_name):
                return self.trans[t].transform(data, scale=scale)
        
        return data

# %%
trans_util = TransUtil(df2, exclude_cols=None) # data standardization

# %%
def generate_xy_pair(final_df, seq_len, trans_util, columns_x, columns_y):
    data_x = pd.DataFrame()
    for c in columns_x:
        data_x[c] = trans_util.transform(final_df[c].fillna(final_df[c].median()), c)

    data_y = pd.DataFrame()
    for c in columns_y:
        data_y[c] = trans_util.transform(final_df[c].fillna(final_df[c].median()), c, scale=False)

    data_x = data_x.values
    data_y = data_y.values
    
    print(data_x.shape, data_y.shape)

    d_x = []
    d_y = []
    for i in range(len(data_x)-seq_len*2+1):
        _x = data_x[i:i+seq_len]
        _y = data_y[i+seq_len:i+seq_len+seq_len]

        assert len(_x) == len(_y) == seq_len, (_x, _y, _x.shape, _y.shape, i, len(data_x))

        d_x.append(_x.T)
        d_y.append(_y.T)

    return np.asarray(d_x).transpose((0, 2, 1)), np.asarray(d_y).transpose((0, 2, 1))

# %%
data_x, data_y = generate_xy_pair(df2, seq_len=SEQ_LEN, trans_util=trans_util, columns_x=COLUMNS_X, columns_y=COLUMNS_Y)

# %%
data_x.shape, data_y.shape

# %%
data_x[0], data_y[0]

# %%
# Extract the idx of the corresponding training data/test data according to each test set
_train_idx_1 = df2[df2['time']<test_list1[0]].index.values.tolist()
_train_idx_2 = df2[(df2['time']>test_list1[1])&(df2['time']<test_list1[2])].index.values.tolist()
_train_idx_3 = df2[(df2['time']>test_list1[3])&(df2['time']<test_list1[4])].index.values.tolist()

# Define the three training data periods
train_idx_1 = _train_idx_1[:-SEQ_LEN*2]
train_idx_2 = train_idx_1 + _train_idx_2[:-SEQ_LEN*2]
train_idx_3 = train_idx_2 + _train_idx_3[:-SEQ_LEN*2]

#Define the three test data periods
test_idx_1 = _train_idx_1[-SEQ_LEN]
test_idx_2 = _train_idx_2[-SEQ_LEN]
test_idx_3 = _train_idx_3[-SEQ_LEN]

# %%
len(_train_idx_1), len(_train_idx_2), len(_train_idx_3)#, len(_train_idx_4)

# %%
len(train_idx_1), len(train_idx_2), len(train_idx_3)#, len(train_idx_4)

# %%
test_idx_1, test_idx_2, test_idx_3#, test_idx_4

# %%
train_x_1 = data_x[train_idx_1]
train_y_1 = data_y[train_idx_1]
train_x_2 = data_x[train_idx_2]
train_y_2 = data_y[train_idx_2]
train_x_3 = data_x[train_idx_3]
train_y_3 = data_y[train_idx_3]

test_x_1 = data_x[test_idx_1]
test_x_2 = data_x[test_idx_2]
test_x_3 = data_x[test_idx_3]

FEATURE_SIZE = train_x_1.shape[-1]
OUTPUT_SIZE = train_y_1.shape[-1]

# %%
class Tt(nn.Module):
    def __init__(self,
                 seq_len,
                 feature_size,
                 output_size,
                 device,
                 use_model='lstm',
                 hidden_size=576,
                 num_hidden_layers=6,
                 num_attention_heads=6,
                 intermediate_size=3072,
                 hidden_act="gelu",
                 hidden_dropout_prob=0.1,
                 attention_probs_dropout_prob=0.1,
                 max_position_embeddings=512,
                 ):
        super(Tt, self).__init__()

        self.device = device
        self.use_model = use_model
        self.feature_size = feature_size

        # location code
        self.position_embeddings = nn.Embedding(max_position_embeddings, hidden_size).to(self.device)
        self.layer_norm = nn.LayerNorm(hidden_size).to(self.device)
        self.fc_inputs = nn.Linear(feature_size, hidden_size).to(self.device)

        encoder_layer = nn.TransformerEncoderLayer(
            hidden_size,
            num_attention_heads,
            intermediate_size,
            dropout=hidden_dropout_prob,
            activation=hidden_act)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_hidden_layers).to(self.device)

        self.lstm = torch.nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, num_layers=2).to(self.device)

        self.fc_output_1 = nn.Linear(hidden_size, hidden_size).to(self.device)
        self.fc_output_2 = nn.Linear(hidden_size, hidden_size).to(self.device)
        self.fc_output_3 = nn.Linear(hidden_size, output_size).to(self.device)

    def forward(self,
                inputs,
                position_ids=None,
                attention_mask=None):

        if position_ids is None:
            # print(inputs.shape[:2])
            ones = torch.ones(inputs.size()[:2], dtype=torch.long, device=self.device)
            seq_length = torch.cumsum(ones, axis=1)
            # seq_length = torch.mean(seq_length, axis=1)
            position_ids = seq_length - ones
            position_ids.stop_gradient = True
        
        # print("positionids",position_ids.size())
        position_embeddings = self.position_embeddings(position_ids)

        # print(self.fc_inputs.weight.dtype)
        inputs = self.fc_inputs(inputs)
        inputs = nn.Tanh()(inputs)

        #print(position_embeddings.size())
        inputs = inputs + position_embeddings

        inputs = self.layer_norm(inputs)

        # Choose to use LSTM or Transformer
        if self.use_model == 'lstm':
            encoder_outputs, (h, c) = self.lstm(inputs)
        elif self.use_model == 'transformer':
            if attention_mask is None:
                attention_mask = torch.unsqueeze(
                    (torch.zeros(inputs.shape[:2])).astype(
                        self.fc_inputs.weight.dtype) * -1e4,
                    axis=[1, 2])

            encoder_outputs = self.encoder(
                inputs,
                src_mask=attention_mask)

        output = self.fc_output_1(encoder_outputs)
        output = nn.ReLU()(output)
        output = self.fc_output_2(output)
        output = self.fc_output_3(output)

        return output

# %%
SEQ_LEN = 168
FEATURE_SIZE = 9
OUTPUT_SIZE = 6
model = Tt(seq_len=SEQ_LEN, feature_size=FEATURE_SIZE, output_size=OUTPUT_SIZE, device=DEVICE)

# %%
def calc_score(y_true, y_pred):
    y_true = np.nan_to_num(y_true)
    y_pred = np.nan_to_num(y_pred)
    return 1/ (1+msle(np.clip(np.reshape(y_true, -1), 0, None), np.clip(np.reshape(y_pred, -1), 0, None)))

def eval_model(model, data_loader):
    model.eval()

    y_pred = []
    y_true = []
    for step, (data, label) in enumerate(data_loader, start=1):
        data = data.to(torch.float32).to(DEVICE)
        label = label.to(torch.float32).to(DEVICE)

        # Computational model output
        output = model(inputs=data)
        y_pred.extend(output.cpu().detach().numpy())
        y_true.extend(label.cpu().detach().numpy())
    
    score = calc_score(y_true, y_pred)
    model.train()
    return score

# %%
# class CustomDataset(Dataset):
#     def __init__(self, data_x, index, data_y=None):
#         self.data_x = data_x
#         self.index = index
#         self.data_y = data_y

#     def __len__(self):
#         return len(self.index)

#     def __getitem__(self, idx):
#         x = self.data_x[self.index[idx]]
#         if self.data_y is not None:
#             y = self.data_y[self.index[idx]]
#         else:
#             y = None
#         return x, y

# %%
# def create_dataloader(data_x, index, batch_size, data_y=None, shuffle=True):
#     data = [{
#         'data': data_x[i], 
#         'label': 0 if data_y is None else data_y[i]} 
#         for i in idx]
#     if data_y is not None:
#         dataset = CustomDataset(data_x, index, data_y)
#     else:
#         dataset = CustomDataset(data_x, index, None)
#     dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)
#     return dataloader

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, data_x, index, data_y):
        self.data_x = data_x
        self.index = index
        self.data_y = data_y

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        x = self.data_x[self.index[idx]]
        if self.data_y is not None:
            y = self.data_y[self.index[idx]]
            return x, y
        else:
            return x

def create_dataloader(data_x, index, batch_size, data_y=None, shuffle=True):
    data = [{
        'data': data_x[i], 
        'label': 0 if data_y is None else data_y[i]} 
        for i in index]
    dataset = CustomDataset(data_x, index, data_y)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)
    return dataloader

# %%
EPOCHS = 30 # 30 epochs they used
BATCH_SIZE = 256
CKPT_DIR = 'work/output'
K_FOLD = 5
epoch_base = 0
step_eval = 1
step_log = 1

def do_train(train_x, train_y, prefix):
    print('-'*5)
    print('training ...', prefix)
    print('train x:', train_x.shape, 'train y:', train_y.shape)

    torch.manual_seed(2022)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    for kfold, tv_idx in enumerate(KFold(n_splits=K_FOLD, shuffle=True, random_state=2022).split(train_x)):
        print('training fold...', kfold)

        train_idx, valid_idx = tv_idx

        model = Tt(seq_len=SEQ_LEN, feature_size=FEATURE_SIZE, output_size=OUTPUT_SIZE, device=DEVICE)
        model = model.to(device)

        train_data_loader = create_dataloader(
            train_x, train_idx, BATCH_SIZE, data_y=train_y, shuffle=True)
        valid_data_loader = create_dataloader(
            train_x, valid_idx, BATCH_SIZE, data_y=train_y, shuffle=False)

        optimizer = optim.AdamW(model.parameters(), lr=1e-4)
        criterion = nn.MSELoss()

        epochs = EPOCHS # training rounds
        save_dir = CKPT_DIR #Folder to save model parameters during training
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

        global_step = 0 #iterations
        tic_train = time.time()

        model.train()

        best_score = 0
        for epoch in range(1+epoch_base, epochs+epoch_base+1):
            for step, (data, label) in enumerate(train_data_loader, start=1):
                data = data.to(torch.float32).to(device)
                label = label.to(torch.float32).to(device)

                # Computational model output
                # print(data.dtype)
                output = model(inputs=data)
                loss = criterion(output, label)
                # print(loss)

                # Print loss function value, accuracy rate, calculation speed
                global_step += 1
                if global_step % step_eval == 0:
                    score = eval_model(model, valid_data_loader)            
                    if score > best_score:
                        # print('saving best model...', score)
                        save_path = os.path.join(save_dir, f'{prefix}_kfold_{kfold}_best_model.pth')
                        torch.save(model.state_dict(), save_path)
                        best_score = score
                    if global_step % step_log == 0:
                        print(
                            'global step %d, epoch: %d, batch: %d, loss: %.5f, valid score: %.5f, speed: %.2f step/s'
                            % (global_step, epoch, step, loss.item(), score,
                                10 / (time.time() - tic_train)))
                        tic_train = time.time()

                # Reverse gradient return, update parameters
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

# %%
def do_pred(test_x, prefix):
    print('-'*6)
    print('predict ...', prefix)
    print('predict x:', test_x.shape)

    # predict
    test_data_loader = create_dataloader(
            [test_x], [0], BATCH_SIZE, data_y=None, shuffle=False)

    sub_df = []
    save_dir = CKPT_DIR

    for kfold in range(K_FOLD):
        print('predict kfold...', kfold)
        model = Tt(seq_len=SEQ_LEN, feature_size=FEATURE_SIZE, output_size=OUTPUT_SIZE, device=DEVICE)
        model.load_state_dict(torch.load(os.path.join(save_dir, '{}_kfold_{}_best_model.pth'.format(prefix, kfold))))
        model = model.to(DEVICE)
        model.eval()

        y_pred = []
        with torch.no_grad():
            for step, (data, label) in enumerate(test_data_loader, start=1):
                data = data.to(torch.float).to(DEVICE)
                label = label.to(torch.float).to(DEVICE)

                # Computational model output
                output = model(inputs=data)
                y_pred.extend(output.cpu().numpy())

        sub_df.append(np.clip(y_pred, 0, None))

    return sub_df

# %%
# Train the model corresponding to each test set in turn
do_train(train_x_1, train_y_1, 'm1')
do_train(train_x_2, train_y_2, 'm2')
do_train(train_x_3, train_y_3, 'm3')
# Out:
# -----
# training ... m1
# train x: (2084, 168, 9) train y: (2084, 168, 6)
# training fold... 0
# global step 1, epoch: 1, batch: 1, loss: 5725.63330, valid score: 0.08200, speed: 11.29 step/s
# global step 2, epoch: 1, batch: 2, loss: 5907.46777, valid score: 0.08233, speed: 7.54 step/s
# global step 3, epoch: 1, batch: 3, loss: 6074.21045, valid score: 0.08280, speed: 7.59 step/s
# global step 4, epoch: 1, batch: 4, loss: 5916.11133, valid score: 0.08329, speed: 7.65 step/s
# global step 5, epoch: 1, batch: 5, loss: 5814.62354, valid score: 0.08382, speed: 7.59 step/s
# global step 6, epoch: 1, batch: 6, loss: 5775.87646, valid score: 0.08441, speed: 7.17 step/s
# global step 7, epoch: 1, batch: 7, loss: 6083.91309, valid score: 0.08508, speed: 7.47 step/s
# global step 8, epoch: 2, batch: 1, loss: 6010.03320, valid score: 0.08586, speed: 8.32 step/s
# global step 9, epoch: 2, batch: 2, loss: 5869.51611, valid score: 0.08680, speed: 6.47 step/s
# global step 10, epoch: 2, batch: 3, loss: 5794.95654, valid score: 0.08794, speed: 7.42 step/s
# global step 11, epoch: 2, batch: 4, loss: 5919.51709, valid score: 0.08936, speed: 7.54 step/s
# global step 12, epoch: 2, batch: 5, loss: 5783.99268, valid score: 0.09114, speed: 7.59 step/s
# global step 13, epoch: 2, batch: 6, loss: 5838.58789, valid score: 0.09340, speed: 6.47 step/s
# global step 14, epoch: 2, batch: 7, loss: 5776.28467, valid score: 0.09630, speed: 8.10 step/s
# global step 15, epoch: 3, batch: 1, loss: 5794.99512, valid score: 0.10002, speed: 9.32 step/s
# global step 16, epoch: 3, batch: 2, loss: 5667.79443, valid score: 0.10482, speed: 7.45 step/s
# global step 17, epoch: 3, batch: 3, loss: 5580.84082, valid score: 0.11100, speed: 6.85 step/s
# global step 18, epoch: 3, batch: 4, loss: 5964.56885, valid score: 0.11893, speed: 6.83 step/s
# global step 19, epoch: 3, batch: 5, loss: 5719.01270, valid score: 0.12887, speed: 7.66 step/s
# global step 20, epoch: 3, batch: 6, loss: 5677.75146, valid score: 0.14106, speed: 7.68 step/s
# global step 21, epoch: 3, batch: 7, loss: 5510.67676, valid score: 0.15548, speed: 8.46 step/s
# global step 22, epoch: 4, batch: 1, loss: 5404.02930, valid score: 0.17189, speed: 9.75 step/s
# global step 23, epoch: 4, batch: 2, loss: 5322.14600, valid score: 0.18983, speed: 7.76 step/s
# global step 24, epoch: 4, batch: 3, loss: 5317.58105, valid score: 0.20896, speed: 7.75 step/s
# global step 25, epoch: 4, batch: 4, loss: 5119.36816, valid score: 0.22912, speed: 6.77 step/s
# global step 26, epoch: 4, batch: 5, loss: 4881.77295, valid score: 0.25030, speed: 7.93 step/s
# global step 27, epoch: 4, batch: 6, loss: 4930.83887, valid score: 0.27255, speed: 7.27 step/s
# global step 28, epoch: 4, batch: 7, loss: 4813.36621, valid score: 0.29595, speed: 7.87 step/s
# global step 29, epoch: 5, batch: 1, loss: 4674.58154, valid score: 0.32059, speed: 8.67 step/s
# global step 30, epoch: 5, batch: 2, loss: 4282.98633, valid score: 0.34644, speed: 7.88 step/s
# global step 31, epoch: 5, batch: 3, loss: 4431.99023, valid score: 0.37341, speed: 8.11 step/s
# global step 32, epoch: 5, batch: 4, loss: 4041.24023, valid score: 0.40136, speed: 7.91 step/s
# global step 33, epoch: 5, batch: 5, loss: 4158.50781, valid score: 0.42999, speed: 7.92 step/s
# global step 34, epoch: 5, batch: 6, loss: 3863.04663, valid score: 0.45903, speed: 8.05 step/s
# global step 35, epoch: 5, batch: 7, loss: 3764.54883, valid score: 0.48814, speed: 8.81 step/s
# global step 36, epoch: 6, batch: 1, loss: 3510.27954, valid score: 0.51704, speed: 9.94 step/s
# global step 37, epoch: 6, batch: 2, loss: 3295.40601, valid score: 0.54536, speed: 7.87 step/s
# global step 38, epoch: 6, batch: 3, loss: 3279.26587, valid score: 0.57277, speed: 7.90 step/s
# global step 39, epoch: 6, batch: 4, loss: 3042.20947, valid score: 0.59893, speed: 7.31 step/s
# global step 40, epoch: 6, batch: 5, loss: 3071.48584, valid score: 0.62347, speed: 7.14 step/s
# global step 41, epoch: 6, batch: 6, loss: 2562.04883, valid score: 0.64586, speed: 8.16 step/s
# global step 42, epoch: 6, batch: 7, loss: 2590.34131, valid score: 0.66514, speed: 8.98 step/s
# global step 43, epoch: 7, batch: 1, loss: 2442.89111, valid score: 0.67950, speed: 10.08 step/s
# global step 44, epoch: 7, batch: 2, loss: 2233.50903, valid score: 0.68564, speed: 7.86 step/s
# global step 45, epoch: 7, batch: 3, loss: 2198.92627, valid score: 0.67991, speed: 11.00 step/s
# global step 46, epoch: 7, batch: 4, loss: 1987.96912, valid score: 0.67038, speed: 10.74 step/s
# global step 47, epoch: 7, batch: 5, loss: 2038.85754, valid score: 0.67148, speed: 10.58 step/s
# global step 48, epoch: 7, batch: 6, loss: 1802.07361, valid score: 0.67124, speed: 10.72 step/s
# global step 49, epoch: 7, batch: 7, loss: 1741.92200, valid score: 0.67004, speed: 11.77 step/s
# global step 50, epoch: 8, batch: 1, loss: 1743.17188, valid score: 0.67289, speed: 13.48 step/s
# global step 51, epoch: 8, batch: 2, loss: 1650.43726, valid score: 0.68572, speed: 7.05 step/s
# global step 52, epoch: 8, batch: 3, loss: 1566.73267, valid score: 0.68911, speed: 7.41 step/s
# global step 53, epoch: 8, batch: 4, loss: 1570.78125, valid score: 0.68535, speed: 10.82 step/s
# global step 54, epoch: 8, batch: 5, loss: 1533.95044, valid score: 0.67898, speed: 10.70 step/s
# global step 55, epoch: 8, batch: 6, loss: 1563.33704, valid score: 0.67402, speed: 10.75 step/s
# global step 56, epoch: 8, batch: 7, loss: 1577.90845, valid score: 0.67245, speed: 11.90 step/s
# global step 57, epoch: 9, batch: 1, loss: 1542.42175, valid score: 0.67448, speed: 13.33 step/s
# global step 58, epoch: 9, batch: 2, loss: 1579.78784, valid score: 0.67930, speed: 10.53 step/s
# global step 59, epoch: 9, batch: 3, loss: 1568.60559, valid score: 0.68515, speed: 10.61 step/s
# global step 60, epoch: 9, batch: 4, loss: 1610.61145, valid score: 0.68944, speed: 8.07 step/s
# global step 61, epoch: 9, batch: 5, loss: 1605.31726, valid score: 0.68992, speed: 8.17 step/s
# global step 62, epoch: 9, batch: 6, loss: 1620.82495, valid score: 0.68703, speed: 10.84 step/s
# global step 63, epoch: 9, batch: 7, loss: 1647.10583, valid score: 0.68500, speed: 11.78 step/s
# global step 64, epoch: 10, batch: 1, loss: 1543.28455, valid score: 0.68821, speed: 13.12 step/s
# global step 65, epoch: 10, batch: 2, loss: 1624.34509, valid score: 0.69594, speed: 7.29 step/s
# global step 66, epoch: 10, batch: 3, loss: 1585.13159, valid score: 0.70464, speed: 8.12 step/s
# global step 67, epoch: 10, batch: 4, loss: 1568.11438, valid score: 0.71137, speed: 8.24 step/s
# global step 68, epoch: 10, batch: 5, loss: 1584.13354, valid score: 0.71542, speed: 7.82 step/s
# global step 69, epoch: 10, batch: 6, loss: 1529.57678, valid score: 0.71770, speed: 7.98 step/s
# global step 70, epoch: 10, batch: 7, loss: 1664.35046, valid score: 0.71943, speed: 8.06 step/s
# global step 71, epoch: 11, batch: 1, loss: 1595.08850, valid score: 0.72124, speed: 9.92 step/s
# global step 72, epoch: 11, batch: 2, loss: 1506.05664, valid score: 0.72355, speed: 8.20 step/s
# global step 73, epoch: 11, batch: 3, loss: 1534.43835, valid score: 0.72608, speed: 8.26 step/s
# global step 74, epoch: 11, batch: 4, loss: 1537.11499, valid score: 0.72846, speed: 7.39 step/s
# global step 75, epoch: 11, batch: 5, loss: 1517.62231, valid score: 0.73009, speed: 7.40 step/s
# global step 76, epoch: 11, batch: 6, loss: 1534.40894, valid score: 0.73080, speed: 8.29 step/s
# global step 77, epoch: 11, batch: 7, loss: 1571.40723, valid score: 0.73082, speed: 9.00 step/s
# global step 78, epoch: 12, batch: 1, loss: 1542.89197, valid score: 0.73071, speed: 14.10 step/s
# global step 79, epoch: 12, batch: 2, loss: 1529.49695, valid score: 0.73094, speed: 8.11 step/s
# global step 80, epoch: 12, batch: 3, loss: 1500.42615, valid score: 0.73154, speed: 7.97 step/s
# global step 81, epoch: 12, batch: 4, loss: 1530.60791, valid score: 0.73226, speed: 8.32 step/s
# global step 82, epoch: 12, batch: 5, loss: 1559.81433, valid score: 0.73273, speed: 8.37 step/s
# global step 83, epoch: 12, batch: 6, loss: 1533.68738, valid score: 0.73272, speed: 10.87 step/s
# global step 84, epoch: 12, batch: 7, loss: 1511.83948, valid score: 0.73226, speed: 12.12 step/s
# global step 85, epoch: 13, batch: 1, loss: 1555.11426, valid score: 0.73163, speed: 13.26 step/s
# global step 86, epoch: 13, batch: 2, loss: 1555.49268, valid score: 0.73102, speed: 10.47 step/s
# global step 87, epoch: 13, batch: 3, loss: 1454.82947, valid score: 0.73052, speed: 10.67 step/s
# global step 88, epoch: 13, batch: 4, loss: 1535.54968, valid score: 0.73023, speed: 10.76 step/s
# global step 89, epoch: 13, batch: 5, loss: 1500.16589, valid score: 0.73006, speed: 10.64 step/s
# global step 90, epoch: 13, batch: 6, loss: 1556.84607, valid score: 0.72988, speed: 10.64 step/s
# global step 91, epoch: 13, batch: 7, loss: 1534.62439, valid score: 0.72951, speed: 11.85 step/s
# global step 92, epoch: 14, batch: 1, loss: 1530.01001, valid score: 0.72880, speed: 13.42 step/s
# global step 93, epoch: 14, batch: 2, loss: 1514.61121, valid score: 0.72789, speed: 10.53 step/s
# global step 94, epoch: 14, batch: 3, loss: 1543.34131, valid score: 0.72694, speed: 10.66 step/s
# global step 95, epoch: 14, batch: 4, loss: 1528.64246, valid score: 0.72599, speed: 10.53 step/s
# global step 96, epoch: 14, batch: 5, loss: 1483.40369, valid score: 0.72505, speed: 10.69 step/s
# global step 97, epoch: 14, batch: 6, loss: 1500.49695, valid score: 0.72426, speed: 10.81 step/s
# global step 98, epoch: 14, batch: 7, loss: 1530.44031, valid score: 0.72355, speed: 11.70 step/s
# global step 99, epoch: 15, batch: 1, loss: 1523.04639, valid score: 0.72295, speed: 13.29 step/s
# global step 100, epoch: 15, batch: 2, loss: 1469.10754, valid score: 0.72246, speed: 10.53 step/s
# global step 101, epoch: 15, batch: 3, loss: 1568.16760, valid score: 0.72224, speed: 10.67 step/s
# global step 102, epoch: 15, batch: 4, loss: 1573.41187, valid score: 0.72212, speed: 10.54 step/s
# global step 103, epoch: 15, batch: 5, loss: 1485.30518, valid score: 0.72214, speed: 10.77 step/s
# global step 104, epoch: 15, batch: 6, loss: 1531.73572, valid score: 0.72240, speed: 10.64 step/s
# global step 105, epoch: 15, batch: 7, loss: 1408.61975, valid score: 0.72277, speed: 11.92 step/s
# global step 106, epoch: 16, batch: 1, loss: 1523.62756, valid score: 0.72338, speed: 13.34 step/s
# global step 107, epoch: 16, batch: 2, loss: 1519.57617, valid score: 0.72404, speed: 10.45 step/s
# global step 108, epoch: 16, batch: 3, loss: 1517.82397, valid score: 0.72467, speed: 10.69 step/s
# global step 109, epoch: 16, batch: 4, loss: 1491.98828, valid score: 0.72526, speed: 10.82 step/s
# global step 110, epoch: 16, batch: 5, loss: 1493.01270, valid score: 0.72595, speed: 10.79 step/s
# global step 111, epoch: 16, batch: 6, loss: 1547.08545, valid score: 0.72663, speed: 10.71 step/s
# global step 112, epoch: 16, batch: 7, loss: 1588.65393, valid score: 0.72720, speed: 11.97 step/s
# global step 113, epoch: 17, batch: 1, loss: 1596.08740, valid score: 0.72762, speed: 13.57 step/s
# global step 114, epoch: 17, batch: 2, loss: 1460.23169, valid score: 0.72788, speed: 10.50 step/s
# global step 115, epoch: 17, batch: 3, loss: 1545.68481, valid score: 0.72815, speed: 10.67 step/s
# global step 116, epoch: 17, batch: 4, loss: 1493.56006, valid score: 0.72836, speed: 10.74 step/s
# global step 117, epoch: 17, batch: 5, loss: 1446.88379, valid score: 0.72868, speed: 10.87 step/s
# global step 118, epoch: 17, batch: 6, loss: 1543.50098, valid score: 0.72906, speed: 10.85 step/s
# global step 119, epoch: 17, batch: 7, loss: 1572.06409, valid score: 0.72937, speed: 12.10 step/s
# global step 120, epoch: 18, batch: 1, loss: 1475.25330, valid score: 0.72967, speed: 13.59 step/s
# global step 121, epoch: 18, batch: 2, loss: 1518.35828, valid score: 0.72995, speed: 10.77 step/s
# global step 122, epoch: 18, batch: 3, loss: 1544.01746, valid score: 0.73016, speed: 11.00 step/s
# global step 123, epoch: 18, batch: 4, loss: 1502.39465, valid score: 0.73026, speed: 10.77 step/s
# global step 124, epoch: 18, batch: 5, loss: 1467.52563, valid score: 0.73031, speed: 10.76 step/s
# global step 125, epoch: 18, batch: 6, loss: 1543.46362, valid score: 0.73032, speed: 10.70 step/s
# global step 126, epoch: 18, batch: 7, loss: 1624.85803, valid score: 0.73019, speed: 12.09 step/s
# global step 127, epoch: 19, batch: 1, loss: 1512.65198, valid score: 0.72998, speed: 13.48 step/s
# global step 128, epoch: 19, batch: 2, loss: 1433.81323, valid score: 0.72968, speed: 10.61 step/s
# global step 129, epoch: 19, batch: 3, loss: 1520.97156, valid score: 0.72952, speed: 10.59 step/s
# global step 130, epoch: 19, batch: 4, loss: 1555.85193, valid score: 0.72936, speed: 10.88 step/s
# global step 131, epoch: 19, batch: 5, loss: 1471.42737, valid score: 0.72920, speed: 10.88 step/s
# global step 132, epoch: 19, batch: 6, loss: 1567.39587, valid score: 0.72908, speed: 11.06 step/s
# global step 133, epoch: 19, batch: 7, loss: 1549.31018, valid score: 0.72889, speed: 12.01 step/s
# global step 134, epoch: 20, batch: 1, loss: 1538.57214, valid score: 0.72861, speed: 13.63 step/s
# global step 135, epoch: 20, batch: 2, loss: 1491.60376, valid score: 0.72840, speed: 10.76 step/s
# global step 136, epoch: 20, batch: 3, loss: 1543.31458, valid score: 0.72822, speed: 10.91 step/s
# global step 137, epoch: 20, batch: 4, loss: 1504.17566, valid score: 0.72811, speed: 10.89 step/s
# global step 138, epoch: 20, batch: 5, loss: 1549.60376, valid score: 0.72808, speed: 10.84 step/s
# global step 139, epoch: 20, batch: 6, loss: 1476.03577, valid score: 0.72805, speed: 11.00 step/s
# global step 140, epoch: 20, batch: 7, loss: 1556.47119, valid score: 0.72804, speed: 11.93 step/s
# global step 141, epoch: 21, batch: 1, loss: 1471.56506, valid score: 0.72803, speed: 13.51 step/s
# global step 142, epoch: 21, batch: 2, loss: 1530.48938, valid score: 0.72813, speed: 10.90 step/s
# global step 143, epoch: 21, batch: 3, loss: 1538.81982, valid score: 0.72817, speed: 10.70 step/s
# global step 144, epoch: 21, batch: 4, loss: 1543.27197, valid score: 0.72823, speed: 10.86 step/s
# global step 145, epoch: 21, batch: 5, loss: 1479.92493, valid score: 0.72824, speed: 10.81 step/s
# global step 146, epoch: 21, batch: 6, loss: 1520.76306, valid score: 0.72828, speed: 11.14 step/s
# global step 147, epoch: 21, batch: 7, loss: 1473.27100, valid score: 0.72836, speed: 12.12 step/s
# global step 148, epoch: 22, batch: 1, loss: 1490.88281, valid score: 0.72856, speed: 13.63 step/s
# global step 149, epoch: 22, batch: 2, loss: 1542.55164, valid score: 0.72883, speed: 10.76 step/s
# global step 150, epoch: 22, batch: 3, loss: 1513.23047, valid score: 0.72908, speed: 11.03 step/s
# global step 151, epoch: 22, batch: 4, loss: 1529.85303, valid score: 0.72934, speed: 10.78 step/s
# global step 152, epoch: 22, batch: 5, loss: 1565.91931, valid score: 0.72949, speed: 10.97 step/s
# global step 153, epoch: 22, batch: 6, loss: 1465.61707, valid score: 0.72949, speed: 10.86 step/s
# global step 154, epoch: 22, batch: 7, loss: 1479.06714, valid score: 0.72954, speed: 11.95 step/s
# global step 155, epoch: 23, batch: 1, loss: 1510.90271, valid score: 0.72965, speed: 13.72 step/s
# global step 156, epoch: 23, batch: 2, loss: 1485.85474, valid score: 0.72972, speed: 10.89 step/s
# global step 157, epoch: 23, batch: 3, loss: 1501.35925, valid score: 0.72980, speed: 10.73 step/s
# global step 158, epoch: 23, batch: 4, loss: 1573.56104, valid score: 0.72993, speed: 10.68 step/s
# global step 159, epoch: 23, batch: 5, loss: 1514.01709, valid score: 0.72991, speed: 10.98 step/s
# global step 160, epoch: 23, batch: 6, loss: 1508.01477, valid score: 0.72987, speed: 11.10 step/s
# global step 161, epoch: 23, batch: 7, loss: 1458.39062, valid score: 0.72976, speed: 11.87 step/s
# global step 162, epoch: 24, batch: 1, loss: 1478.92639, valid score: 0.72972, speed: 13.66 step/s
# global step 163, epoch: 24, batch: 2, loss: 1531.80176, valid score: 0.72974, speed: 10.78 step/s
# global step 164, epoch: 24, batch: 3, loss: 1502.53699, valid score: 0.72972, speed: 10.88 step/s
# global step 165, epoch: 24, batch: 4, loss: 1511.94775, valid score: 0.72970, speed: 10.95 step/s
# global step 166, epoch: 24, batch: 5, loss: 1529.17993, valid score: 0.72976, speed: 11.01 step/s
# global step 167, epoch: 24, batch: 6, loss: 1544.49817, valid score: 0.72966, speed: 10.94 step/s
# global step 168, epoch: 24, batch: 7, loss: 1492.60657, valid score: 0.72954, speed: 12.02 step/s
# global step 169, epoch: 25, batch: 1, loss: 1481.93579, valid score: 0.72950, speed: 13.80 step/s
# global step 170, epoch: 25, batch: 2, loss: 1535.26147, valid score: 0.72944, speed: 10.78 step/s
# global step 171, epoch: 25, batch: 3, loss: 1501.74792, valid score: 0.72937, speed: 10.99 step/s
# global step 172, epoch: 25, batch: 4, loss: 1557.88025, valid score: 0.72931, speed: 10.77 step/s
# global step 173, epoch: 25, batch: 5, loss: 1432.13623, valid score: 0.72921, speed: 10.74 step/s
# global step 174, epoch: 25, batch: 6, loss: 1521.43640, valid score: 0.72930, speed: 10.91 step/s
# global step 175, epoch: 25, batch: 7, loss: 1576.15894, valid score: 0.72939, speed: 12.10 step/s
# global step 176, epoch: 26, batch: 1, loss: 1486.53833, valid score: 0.72950, speed: 13.52 step/s
# global step 177, epoch: 26, batch: 2, loss: 1555.82568, valid score: 0.72976, speed: 10.77 step/s
# global step 178, epoch: 26, batch: 3, loss: 1424.13147, valid score: 0.72985, speed: 10.87 step/s
# global step 179, epoch: 26, batch: 4, loss: 1540.54944, valid score: 0.73006, speed: 10.86 step/s
# global step 180, epoch: 26, batch: 5, loss: 1528.35059, valid score: 0.73017, speed: 10.90 step/s
# global step 181, epoch: 26, batch: 6, loss: 1552.29272, valid score: 0.73021, speed: 10.82 step/s
# global step 182, epoch: 26, batch: 7, loss: 1571.24658, valid score: 0.73014, speed: 12.00 step/s
# global step 183, epoch: 27, batch: 1, loss: 1520.96826, valid score: 0.73007, speed: 13.63 step/s
# global step 184, epoch: 27, batch: 2, loss: 1448.48584, valid score: 0.73004, speed: 10.77 step/s
# global step 185, epoch: 27, batch: 3, loss: 1521.65710, valid score: 0.73015, speed: 10.80 step/s
# global step 186, epoch: 27, batch: 4, loss: 1538.53247, valid score: 0.73018, speed: 10.63 step/s
# global step 187, epoch: 27, batch: 5, loss: 1585.04944, valid score: 0.73025, speed: 10.65 step/s
# global step 188, epoch: 27, batch: 6, loss: 1500.93884, valid score: 0.73017, speed: 10.83 step/s
# global step 189, epoch: 27, batch: 7, loss: 1447.58240, valid score: 0.73005, speed: 12.28 step/s
# global step 190, epoch: 28, batch: 1, loss: 1484.22656, valid score: 0.73000, speed: 13.50 step/s
# global step 191, epoch: 28, batch: 2, loss: 1487.48096, valid score: 0.73000, speed: 10.76 step/s
# global step 192, epoch: 28, batch: 3, loss: 1575.32654, valid score: 0.72999, speed: 10.98 step/s
# global step 193, epoch: 28, batch: 4, loss: 1503.08032, valid score: 0.72987, speed: 10.87 step/s
# global step 194, epoch: 28, batch: 5, loss: 1546.68286, valid score: 0.72987, speed: 10.93 step/s
# global step 195, epoch: 28, batch: 6, loss: 1476.75562, valid score: 0.72987, speed: 10.95 step/s
# global step 196, epoch: 28, batch: 7, loss: 1537.26038, valid score: 0.72985, speed: 12.07 step/s
# global step 197, epoch: 29, batch: 1, loss: 1504.82751, valid score: 0.72984, speed: 13.66 step/s
# global step 198, epoch: 29, batch: 2, loss: 1548.08948, valid score: 0.72987, speed: 10.90 step/s
# global step 199, epoch: 29, batch: 3, loss: 1530.67395, valid score: 0.72986, speed: 10.82 step/s
# global step 200, epoch: 29, batch: 4, loss: 1530.54272, valid score: 0.72988, speed: 10.69 step/s
# global step 201, epoch: 29, batch: 5, loss: 1462.03137, valid score: 0.73000, speed: 10.73 step/s
# global step 202, epoch: 29, batch: 6, loss: 1528.61511, valid score: 0.73010, speed: 10.78 step/s
# global step 203, epoch: 29, batch: 7, loss: 1420.03784, valid score: 0.73015, speed: 12.15 step/s
# global step 204, epoch: 30, batch: 1, loss: 1475.61584, valid score: 0.73023, speed: 13.57 step/s
# global step 205, epoch: 30, batch: 2, loss: 1462.69153, valid score: 0.73032, speed: 10.92 step/s
# global step 206, epoch: 30, batch: 3, loss: 1550.39221, valid score: 0.73044, speed: 10.80 step/s
# global step 207, epoch: 30, batch: 4, loss: 1514.07471, valid score: 0.73054, speed: 10.87 step/s
# global step 208, epoch: 30, batch: 5, loss: 1543.42236, valid score: 0.73059, speed: 10.80 step/s
# global step 209, epoch: 30, batch: 6, loss: 1527.84741, valid score: 0.73056, speed: 10.73 step/s
# global step 210, epoch: 30, batch: 7, loss: 1512.14563, valid score: 0.73050, speed: 12.07 step/s
# training fold... 1
# global step 1, epoch: 1, batch: 1, loss: 5933.78809, valid score: 0.08193, speed: 11.94 step/s
# global step 2, epoch: 1, batch: 2, loss: 5712.93896, valid score: 0.08213, speed: 7.74 step/s
# global step 3, epoch: 1, batch: 3, loss: 6052.81592, valid score: 0.08256, speed: 6.95 step/s
# global step 4, epoch: 1, batch: 4, loss: 6198.16162, valid score: 0.08305, speed: 6.84 step/s
# global step 5, epoch: 1, batch: 5, loss: 5918.22998, valid score: 0.08359, speed: 7.80 step/s
# global step 6, epoch: 1, batch: 6, loss: 5758.49219, valid score: 0.08419, speed: 7.91 step/s
# global step 7, epoch: 1, batch: 7, loss: 5798.22461, valid score: 0.08487, speed: 8.86 step/s
# global step 8, epoch: 2, batch: 1, loss: 5962.68945, valid score: 0.08566, speed: 10.08 step/s
# global step 9, epoch: 2, batch: 2, loss: 5810.03418, valid score: 0.08660, speed: 7.85 step/s
# global step 10, epoch: 2, batch: 3, loss: 5911.28809, valid score: 0.08773, speed: 8.02 step/s
# global step 11, epoch: 2, batch: 4, loss: 5711.88525, valid score: 0.08914, speed: 7.89 step/s
# global step 12, epoch: 2, batch: 5, loss: 5803.28027, valid score: 0.09091, speed: 7.70 step/s
# global step 13, epoch: 2, batch: 6, loss: 6161.22754, valid score: 0.09316, speed: 7.59 step/s
# global step 14, epoch: 2, batch: 7, loss: 5916.36914, valid score: 0.09602, speed: 7.60 step/s
# global step 15, epoch: 3, batch: 1, loss: 6016.49707, valid score: 0.09974, speed: 8.63 step/s
# global step 16, epoch: 3, batch: 2, loss: 5756.45654, valid score: 0.10454, speed: 7.96 step/s
# global step 17, epoch: 3, batch: 3, loss: 5790.57812, valid score: 0.11076, speed: 7.97 step/s
# global step 18, epoch: 3, batch: 4, loss: 5890.58545, valid score: 0.11876, speed: 7.92 step/s
# global step 19, epoch: 3, batch: 5, loss: 5580.14697, valid score: 0.12884, speed: 7.87 step/s
# global step 20, epoch: 3, batch: 6, loss: 5436.68506, valid score: 0.14125, speed: 7.96 step/s
# global step 21, epoch: 3, batch: 7, loss: 5854.02734, valid score: 0.15593, speed: 8.65 step/s
# global step 22, epoch: 4, batch: 1, loss: 5523.19678, valid score: 0.17262, speed: 9.88 step/s
# global step 23, epoch: 4, batch: 2, loss: 5416.64697, valid score: 0.19105, speed: 7.98 step/s
# global step 24, epoch: 4, batch: 3, loss: 5053.66113, valid score: 0.21101, speed: 6.96 step/s
# global step 25, epoch: 4, batch: 4, loss: 5180.08398, valid score: 0.23243, speed: 6.95 step/s
# global step 26, epoch: 4, batch: 5, loss: 5138.51807, valid score: 0.25519, speed: 8.06 step/s
# global step 27, epoch: 4, batch: 6, loss: 4872.55664, valid score: 0.27918, speed: 7.83 step/s
# global step 28, epoch: 4, batch: 7, loss: 4942.25342, valid score: 0.30439, speed: 8.77 step/s
# global step 29, epoch: 5, batch: 1, loss: 4375.83252, valid score: 0.33092, speed: 9.89 step/s
# global step 30, epoch: 5, batch: 2, loss: 4474.19336, valid score: 0.35880, speed: 7.74 step/s
# global step 31, epoch: 5, batch: 3, loss: 4375.34619, valid score: 0.38798, speed: 8.12 step/s
# global step 32, epoch: 5, batch: 4, loss: 4027.68896, valid score: 0.41825, speed: 6.81 step/s
# global step 33, epoch: 5, batch: 5, loss: 4217.27100, valid score: 0.44933, speed: 7.83 step/s
# global step 34, epoch: 5, batch: 6, loss: 3987.25952, valid score: 0.48088, speed: 7.30 step/s
# global step 35, epoch: 5, batch: 7, loss: 3989.42065, valid score: 0.51244, speed: 7.88 step/s
# global step 36, epoch: 6, batch: 1, loss: 3417.42285, valid score: 0.54346, speed: 9.09 step/s
# global step 37, epoch: 6, batch: 2, loss: 3289.22705, valid score: 0.57310, speed: 7.74 step/s
# global step 38, epoch: 6, batch: 3, loss: 3241.62427, valid score: 0.60021, speed: 7.89 step/s
# global step 39, epoch: 6, batch: 4, loss: 3229.18774, valid score: 0.62306, speed: 8.05 step/s
# global step 40, epoch: 6, batch: 5, loss: 2906.29663, valid score: 0.63968, speed: 8.07 step/s
# global step 41, epoch: 6, batch: 6, loss: 2782.24219, valid score: 0.64994, speed: 7.84 step/s
# global step 42, epoch: 6, batch: 7, loss: 2416.49341, valid score: 0.65733, speed: 8.84 step/s
# global step 43, epoch: 7, batch: 1, loss: 2373.55347, valid score: 0.66546, speed: 9.90 step/s
# global step 44, epoch: 7, batch: 2, loss: 2233.41309, valid score: 0.67444, speed: 7.98 step/s
# global step 45, epoch: 7, batch: 3, loss: 2264.31567, valid score: 0.68147, speed: 7.48 step/s
# global step 46, epoch: 7, batch: 4, loss: 1999.50952, valid score: 0.68410, speed: 6.95 step/s
# global step 47, epoch: 7, batch: 5, loss: 1978.77551, valid score: 0.68196, speed: 10.75 step/s
# global step 48, epoch: 7, batch: 6, loss: 1895.00342, valid score: 0.67716, speed: 10.58 step/s
# global step 49, epoch: 7, batch: 7, loss: 1674.02356, valid score: 0.67259, speed: 11.88 step/s
# global step 50, epoch: 8, batch: 1, loss: 1747.90234, valid score: 0.67029, speed: 13.17 step/s
# global step 51, epoch: 8, batch: 2, loss: 1584.56116, valid score: 0.67046, speed: 10.43 step/s
# global step 52, epoch: 8, batch: 3, loss: 1677.69360, valid score: 0.67191, speed: 10.44 step/s
# global step 53, epoch: 8, batch: 4, loss: 1617.75891, valid score: 0.67244, speed: 10.49 step/s
# global step 54, epoch: 8, batch: 5, loss: 1634.61963, valid score: 0.67123, speed: 10.39 step/s
# global step 55, epoch: 8, batch: 6, loss: 1570.42822, valid score: 0.67065, speed: 10.49 step/s
# global step 56, epoch: 8, batch: 7, loss: 1474.50049, valid score: 0.67327, speed: 11.91 step/s
# global step 57, epoch: 9, batch: 1, loss: 1559.12805, valid score: 0.67710, speed: 13.14 step/s
# global step 58, epoch: 9, batch: 2, loss: 1600.46143, valid score: 0.67940, speed: 10.30 step/s
# global step 59, epoch: 9, batch: 3, loss: 1628.64612, valid score: 0.68000, speed: 10.24 step/s
# global step 60, epoch: 9, batch: 4, loss: 1619.38208, valid score: 0.68070, speed: 10.49 step/s
# global step 61, epoch: 9, batch: 5, loss: 1628.19824, valid score: 0.68295, speed: 10.53 step/s
# global step 62, epoch: 9, batch: 6, loss: 1588.96497, valid score: 0.68650, speed: 8.07 step/s
# global step 63, epoch: 9, batch: 7, loss: 1618.05005, valid score: 0.69042, speed: 8.97 step/s
# global step 64, epoch: 10, batch: 1, loss: 1625.18835, valid score: 0.69371, speed: 10.12 step/s
# global step 65, epoch: 10, batch: 2, loss: 1595.69653, valid score: 0.69717, speed: 7.81 step/s
# global step 66, epoch: 10, batch: 3, loss: 1546.32178, valid score: 0.70211, speed: 8.09 step/s
# global step 67, epoch: 10, batch: 4, loss: 1540.71899, valid score: 0.70789, speed: 8.17 step/s
# global step 68, epoch: 10, batch: 5, loss: 1549.72034, valid score: 0.71288, speed: 8.32 step/s
# global step 69, epoch: 10, batch: 6, loss: 1584.90405, valid score: 0.71652, speed: 7.62 step/s
# global step 70, epoch: 10, batch: 7, loss: 1532.59973, valid score: 0.71947, speed: 7.99 step/s
# global step 71, epoch: 11, batch: 1, loss: 1541.73279, valid score: 0.72239, speed: 7.99 step/s
# global step 72, epoch: 11, batch: 2, loss: 1512.78186, valid score: 0.72526, speed: 7.92 step/s
# global step 73, epoch: 11, batch: 3, loss: 1553.70837, valid score: 0.72763, speed: 8.30 step/s
# global step 74, epoch: 11, batch: 4, loss: 1534.49707, valid score: 0.72904, speed: 8.46 step/s
# global step 75, epoch: 11, batch: 5, loss: 1500.45374, valid score: 0.72957, speed: 8.47 step/s
# global step 76, epoch: 11, batch: 6, loss: 1572.56750, valid score: 0.72977, speed: 8.48 step/s
# global step 77, epoch: 11, batch: 7, loss: 1532.03076, valid score: 0.72997, speed: 9.06 step/s
# global step 78, epoch: 12, batch: 1, loss: 1507.70300, valid score: 0.73004, speed: 9.85 step/s
# global step 79, epoch: 12, batch: 2, loss: 1535.68835, valid score: 0.72987, speed: 11.26 step/s
# global step 80, epoch: 12, batch: 3, loss: 1563.33142, valid score: 0.72956, speed: 11.02 step/s
# global step 81, epoch: 12, batch: 4, loss: 1463.84705, valid score: 0.72937, speed: 10.62 step/s
# global step 82, epoch: 12, batch: 5, loss: 1581.03589, valid score: 0.72964, speed: 10.59 step/s
# global step 83, epoch: 12, batch: 6, loss: 1546.19238, valid score: 0.73009, speed: 8.13 step/s
# global step 84, epoch: 12, batch: 7, loss: 1554.23022, valid score: 0.73056, speed: 9.15 step/s
# global step 85, epoch: 13, batch: 1, loss: 1522.16602, valid score: 0.73072, speed: 9.53 step/s
# global step 86, epoch: 13, batch: 2, loss: 1478.42322, valid score: 0.73062, speed: 11.12 step/s
# global step 87, epoch: 13, batch: 3, loss: 1493.13550, valid score: 0.73030, speed: 10.77 step/s
# global step 88, epoch: 13, batch: 4, loss: 1563.93140, valid score: 0.72987, speed: 10.81 step/s
# global step 89, epoch: 13, batch: 5, loss: 1512.99866, valid score: 0.72921, speed: 10.82 step/s
# global step 90, epoch: 13, batch: 6, loss: 1567.24268, valid score: 0.72832, speed: 10.84 step/s
# global step 91, epoch: 13, batch: 7, loss: 1571.14185, valid score: 0.72716, speed: 12.02 step/s
# global step 92, epoch: 14, batch: 1, loss: 1513.92053, valid score: 0.72588, speed: 13.65 step/s
# global step 93, epoch: 14, batch: 2, loss: 1557.15857, valid score: 0.72469, speed: 10.78 step/s
# global step 94, epoch: 14, batch: 3, loss: 1569.94653, valid score: 0.72374, speed: 10.62 step/s
# global step 95, epoch: 14, batch: 4, loss: 1499.52856, valid score: 0.72294, speed: 10.79 step/s
# global step 96, epoch: 14, batch: 5, loss: 1465.21741, valid score: 0.72228, speed: 10.80 step/s
# global step 97, epoch: 14, batch: 6, loss: 1504.93884, valid score: 0.72170, speed: 11.03 step/s
# global step 98, epoch: 14, batch: 7, loss: 1551.12402, valid score: 0.72121, speed: 11.99 step/s
# global step 99, epoch: 15, batch: 1, loss: 1493.03674, valid score: 0.72060, speed: 13.52 step/s
# global step 100, epoch: 15, batch: 2, loss: 1549.97070, valid score: 0.72001, speed: 10.62 step/s
# global step 101, epoch: 15, batch: 3, loss: 1457.46497, valid score: 0.71952, speed: 10.89 step/s
# global step 102, epoch: 15, batch: 4, loss: 1559.00732, valid score: 0.71922, speed: 10.92 step/s
# global step 103, epoch: 15, batch: 5, loss: 1547.62671, valid score: 0.71908, speed: 10.66 step/s
# global step 104, epoch: 15, batch: 6, loss: 1519.68481, valid score: 0.71923, speed: 10.80 step/s
# global step 105, epoch: 15, batch: 7, loss: 1528.91199, valid score: 0.71971, speed: 11.86 step/s
# global step 106, epoch: 16, batch: 1, loss: 1509.63037, valid score: 0.72029, speed: 13.42 step/s
# global step 107, epoch: 16, batch: 2, loss: 1499.93799, valid score: 0.72089, speed: 10.58 step/s
# global step 108, epoch: 16, batch: 3, loss: 1603.31812, valid score: 0.72157, speed: 10.50 step/s
# global step 109, epoch: 16, batch: 4, loss: 1484.48523, valid score: 0.72210, speed: 10.54 step/s
# global step 110, epoch: 16, batch: 5, loss: 1502.78918, valid score: 0.72257, speed: 10.56 step/s
# global step 111, epoch: 16, batch: 6, loss: 1489.87830, valid score: 0.72311, speed: 10.82 step/s
# global step 112, epoch: 16, batch: 7, loss: 1541.04858, valid score: 0.72374, speed: 12.09 step/s
# global step 113, epoch: 17, batch: 1, loss: 1488.40137, valid score: 0.72427, speed: 13.35 step/s
# global step 114, epoch: 17, batch: 2, loss: 1564.45581, valid score: 0.72483, speed: 10.75 step/s
# global step 115, epoch: 17, batch: 3, loss: 1541.03284, valid score: 0.72544, speed: 10.70 step/s
# global step 116, epoch: 17, batch: 4, loss: 1520.32617, valid score: 0.72603, speed: 10.49 step/s
# global step 117, epoch: 17, batch: 5, loss: 1526.22925, valid score: 0.72647, speed: 10.57 step/s
# global step 118, epoch: 17, batch: 6, loss: 1490.77209, valid score: 0.72685, speed: 10.74 step/s
# global step 119, epoch: 17, batch: 7, loss: 1491.31287, valid score: 0.72721, speed: 11.85 step/s
# global step 120, epoch: 18, batch: 1, loss: 1510.21851, valid score: 0.72745, speed: 13.35 step/s
# global step 121, epoch: 18, batch: 2, loss: 1511.61047, valid score: 0.72755, speed: 10.55 step/s
# global step 122, epoch: 18, batch: 3, loss: 1538.76746, valid score: 0.72763, speed: 10.42 step/s
# global step 123, epoch: 18, batch: 4, loss: 1519.56384, valid score: 0.72759, speed: 10.46 step/s
# global step 124, epoch: 18, batch: 5, loss: 1518.11389, valid score: 0.72752, speed: 10.54 step/s
# global step 125, epoch: 18, batch: 6, loss: 1522.39746, valid score: 0.72739, speed: 10.65 step/s
# global step 126, epoch: 18, batch: 7, loss: 1495.19507, valid score: 0.72732, speed: 12.06 step/s
# global step 127, epoch: 19, batch: 1, loss: 1574.30420, valid score: 0.72736, speed: 13.48 step/s
# global step 128, epoch: 19, batch: 2, loss: 1457.09631, valid score: 0.72734, speed: 10.68 step/s
# global step 129, epoch: 19, batch: 3, loss: 1460.72925, valid score: 0.72734, speed: 10.73 step/s
# global step 130, epoch: 19, batch: 4, loss: 1522.91431, valid score: 0.72731, speed: 10.78 step/s
# global step 131, epoch: 19, batch: 5, loss: 1476.28870, valid score: 0.72721, speed: 10.73 step/s
# global step 132, epoch: 19, batch: 6, loss: 1565.68213, valid score: 0.72709, speed: 10.81 step/s
# global step 133, epoch: 19, batch: 7, loss: 1569.13416, valid score: 0.72677, speed: 11.82 step/s
# global step 134, epoch: 20, batch: 1, loss: 1551.64172, valid score: 0.72632, speed: 13.39 step/s
# global step 135, epoch: 20, batch: 2, loss: 1495.07898, valid score: 0.72586, speed: 10.62 step/s
# global step 136, epoch: 20, batch: 3, loss: 1529.33569, valid score: 0.72562, speed: 10.60 step/s
# global step 137, epoch: 20, batch: 4, loss: 1460.03101, valid score: 0.72560, speed: 10.53 step/s
# global step 138, epoch: 20, batch: 5, loss: 1509.97351, valid score: 0.72568, speed: 10.74 step/s
# global step 139, epoch: 20, batch: 6, loss: 1526.57605, valid score: 0.72561, speed: 10.96 step/s
# global step 140, epoch: 20, batch: 7, loss: 1594.66272, valid score: 0.72551, speed: 11.84 step/s
# global step 141, epoch: 21, batch: 1, loss: 1539.87317, valid score: 0.72537, speed: 13.35 step/s
# global step 142, epoch: 21, batch: 2, loss: 1554.77417, valid score: 0.72522, speed: 10.70 step/s
# global step 143, epoch: 21, batch: 3, loss: 1491.49390, valid score: 0.72499, speed: 10.57 step/s
# global step 144, epoch: 21, batch: 4, loss: 1567.07056, valid score: 0.72503, speed: 10.67 step/s
# global step 145, epoch: 21, batch: 5, loss: 1500.26990, valid score: 0.72518, speed: 10.78 step/s
# global step 146, epoch: 21, batch: 6, loss: 1499.11401, valid score: 0.72549, speed: 10.76 step/s
# global step 147, epoch: 21, batch: 7, loss: 1445.33911, valid score: 0.72578, speed: 11.87 step/s
# global step 148, epoch: 22, batch: 1, loss: 1509.57397, valid score: 0.72594, speed: 13.38 step/s
# global step 149, epoch: 22, batch: 2, loss: 1470.65344, valid score: 0.72608, speed: 10.71 step/s
# global step 150, epoch: 22, batch: 3, loss: 1527.90869, valid score: 0.72618, speed: 10.44 step/s
# global step 151, epoch: 22, batch: 4, loss: 1503.90833, valid score: 0.72617, speed: 10.61 step/s
# global step 152, epoch: 22, batch: 5, loss: 1503.59302, valid score: 0.72628, speed: 10.71 step/s
# global step 153, epoch: 22, batch: 6, loss: 1546.16016, valid score: 0.72641, speed: 10.71 step/s
# global step 154, epoch: 22, batch: 7, loss: 1597.34094, valid score: 0.72659, speed: 12.05 step/s
# global step 155, epoch: 23, batch: 1, loss: 1535.61243, valid score: 0.72667, speed: 13.36 step/s
# global step 156, epoch: 23, batch: 2, loss: 1470.17468, valid score: 0.72679, speed: 10.61 step/s
# global step 157, epoch: 23, batch: 3, loss: 1537.01270, valid score: 0.72689, speed: 10.81 step/s
# global step 158, epoch: 23, batch: 4, loss: 1536.70691, valid score: 0.72683, speed: 10.69 step/s
# global step 159, epoch: 23, batch: 5, loss: 1502.88586, valid score: 0.72691, speed: 10.81 step/s
# global step 160, epoch: 23, batch: 6, loss: 1496.62732, valid score: 0.72685, speed: 10.71 step/s
# global step 161, epoch: 23, batch: 7, loss: 1552.22375, valid score: 0.72689, speed: 11.92 step/s
# global step 162, epoch: 24, batch: 1, loss: 1496.09900, valid score: 0.72692, speed: 13.44 step/s
# global step 163, epoch: 24, batch: 2, loss: 1528.33118, valid score: 0.72693, speed: 10.68 step/s
# global step 164, epoch: 24, batch: 3, loss: 1520.64893, valid score: 0.72689, speed: 10.61 step/s
# global step 165, epoch: 24, batch: 4, loss: 1573.68555, valid score: 0.72674, speed: 10.76 step/s
# global step 166, epoch: 24, batch: 5, loss: 1508.96545, valid score: 0.72661, speed: 10.60 step/s
# global step 167, epoch: 24, batch: 6, loss: 1471.34338, valid score: 0.72654, speed: 10.78 step/s
# global step 168, epoch: 24, batch: 7, loss: 1471.52283, valid score: 0.72661, speed: 12.17 step/s
# global step 169, epoch: 25, batch: 1, loss: 1492.27539, valid score: 0.72689, speed: 13.49 step/s
# global step 170, epoch: 25, batch: 2, loss: 1537.09827, valid score: 0.72719, speed: 10.58 step/s
# global step 171, epoch: 25, batch: 3, loss: 1502.90979, valid score: 0.72736, speed: 10.65 step/s
# global step 172, epoch: 25, batch: 4, loss: 1484.87134, valid score: 0.72752, speed: 10.84 step/s
# global step 173, epoch: 25, batch: 5, loss: 1594.90771, valid score: 0.72770, speed: 10.76 step/s
# global step 174, epoch: 25, batch: 6, loss: 1488.86670, valid score: 0.72768, speed: 10.77 step/s
# global step 175, epoch: 25, batch: 7, loss: 1498.56018, valid score: 0.72759, speed: 11.86 step/s
# global step 176, epoch: 26, batch: 1, loss: 1480.87842, valid score: 0.72745, speed: 13.61 step/s
# global step 177, epoch: 26, batch: 2, loss: 1507.82544, valid score: 0.72753, speed: 10.60 step/s
# global step 178, epoch: 26, batch: 3, loss: 1496.43457, valid score: 0.72763, speed: 10.69 step/s
# global step 179, epoch: 26, batch: 4, loss: 1567.62488, valid score: 0.72761, speed: 10.60 step/s
# global step 180, epoch: 26, batch: 5, loss: 1530.66675, valid score: 0.72751, speed: 10.69 step/s
# global step 181, epoch: 26, batch: 6, loss: 1533.19763, valid score: 0.72727, speed: 10.86 step/s
# global step 182, epoch: 26, batch: 7, loss: 1464.72571, valid score: 0.72702, speed: 12.05 step/s
# global step 183, epoch: 27, batch: 1, loss: 1502.26001, valid score: 0.72682, speed: 13.53 step/s
# global step 184, epoch: 27, batch: 2, loss: 1510.77014, valid score: 0.72657, speed: 10.74 step/s
# global step 185, epoch: 27, batch: 3, loss: 1532.34070, valid score: 0.72657, speed: 10.74 step/s
# global step 186, epoch: 27, batch: 4, loss: 1481.84180, valid score: 0.72658, speed: 10.97 step/s
# global step 187, epoch: 27, batch: 5, loss: 1521.38892, valid score: 0.72677, speed: 10.74 step/s
# global step 188, epoch: 27, batch: 6, loss: 1514.62427, valid score: 0.72682, speed: 10.85 step/s
# global step 189, epoch: 27, batch: 7, loss: 1586.21204, valid score: 0.72687, speed: 11.89 step/s
# global step 190, epoch: 28, batch: 1, loss: 1471.68164, valid score: 0.72690, speed: 13.56 step/s
# global step 191, epoch: 28, batch: 2, loss: 1523.13391, valid score: 0.72698, speed: 10.72 step/s
# global step 192, epoch: 28, batch: 3, loss: 1519.53259, valid score: 0.72707, speed: 10.69 step/s
# global step 193, epoch: 28, batch: 4, loss: 1502.23511, valid score: 0.72713, speed: 10.63 step/s
# global step 194, epoch: 28, batch: 5, loss: 1483.42712, valid score: 0.72734, speed: 10.66 step/s
# global step 195, epoch: 28, batch: 6, loss: 1578.77283, valid score: 0.72766, speed: 10.74 step/s
# global step 196, epoch: 28, batch: 7, loss: 1555.38672, valid score: 0.72777, speed: 12.28 step/s
# global step 197, epoch: 29, batch: 1, loss: 1505.91431, valid score: 0.72777, speed: 13.50 step/s
# global step 198, epoch: 29, batch: 2, loss: 1505.77722, valid score: 0.72776, speed: 10.75 step/s
# global step 199, epoch: 29, batch: 3, loss: 1514.22302, valid score: 0.72767, speed: 10.78 step/s
# global step 200, epoch: 29, batch: 4, loss: 1504.20789, valid score: 0.72757, speed: 10.71 step/s
# global step 201, epoch: 29, batch: 5, loss: 1521.54492, valid score: 0.72759, speed: 10.77 step/s
# global step 202, epoch: 29, batch: 6, loss: 1547.27673, valid score: 0.72757, speed: 10.89 step/s
# global step 203, epoch: 29, batch: 7, loss: 1521.81531, valid score: 0.72754, speed: 12.09 step/s
# global step 204, epoch: 30, batch: 1, loss: 1540.71680, valid score: 0.72756, speed: 13.62 step/s
# global step 205, epoch: 30, batch: 2, loss: 1536.79919, valid score: 0.72750, speed: 10.67 step/s
# global step 206, epoch: 30, batch: 3, loss: 1479.32300, valid score: 0.72734, speed: 10.85 step/s
# global step 207, epoch: 30, batch: 4, loss: 1507.16882, valid score: 0.72717, speed: 10.62 step/s
# global step 208, epoch: 30, batch: 5, loss: 1486.03003, valid score: 0.72701, speed: 10.89 step/s
# global step 209, epoch: 30, batch: 6, loss: 1508.37781, valid score: 0.72715, speed: 10.62 step/s
# global step 210, epoch: 30, batch: 7, loss: 1595.85730, valid score: 0.72742, speed: 12.19 step/s
# training fold... 2
# global step 1, epoch: 1, batch: 1, loss: 5868.93604, valid score: 0.08115, speed: 11.54 step/s
# global step 2, epoch: 1, batch: 2, loss: 5829.92383, valid score: 0.08137, speed: 7.67 step/s
# global step 3, epoch: 1, batch: 3, loss: 5997.31299, valid score: 0.08182, speed: 8.00 step/s
# global step 4, epoch: 1, batch: 4, loss: 5681.37207, valid score: 0.08230, speed: 7.83 step/s
# global step 5, epoch: 1, batch: 5, loss: 5792.69287, valid score: 0.08282, speed: 7.90 step/s
# global step 6, epoch: 1, batch: 6, loss: 5904.84668, valid score: 0.08340, speed: 7.84 step/s
# global step 7, epoch: 1, batch: 7, loss: 5915.10400, valid score: 0.08403, speed: 8.62 step/s
# global step 8, epoch: 2, batch: 1, loss: 5753.00635, valid score: 0.08477, speed: 8.69 step/s
# global step 9, epoch: 2, batch: 2, loss: 5802.78418, valid score: 0.08564, speed: 7.08 step/s
# global step 10, epoch: 2, batch: 3, loss: 6007.69043, valid score: 0.08668, speed: 7.75 step/s
# global step 11, epoch: 2, batch: 4, loss: 5913.74512, valid score: 0.08797, speed: 8.10 step/s
# global step 12, epoch: 2, batch: 5, loss: 5957.60645, valid score: 0.08958, speed: 7.98 step/s
# global step 13, epoch: 2, batch: 6, loss: 5637.68896, valid score: 0.09162, speed: 7.77 step/s
# global step 14, epoch: 2, batch: 7, loss: 5637.03467, valid score: 0.09423, speed: 8.93 step/s
# global step 15, epoch: 3, batch: 1, loss: 5698.44580, valid score: 0.09762, speed: 10.06 step/s
# global step 16, epoch: 3, batch: 2, loss: 5819.75830, valid score: 0.10198, speed: 7.67 step/s
# global step 17, epoch: 3, batch: 3, loss: 5651.29688, valid score: 0.10761, speed: 7.82 step/s
# global step 18, epoch: 3, batch: 4, loss: 5582.70361, valid score: 0.11481, speed: 7.85 step/s
# global step 19, epoch: 3, batch: 5, loss: 5894.33008, valid score: 0.12389, speed: 7.22 step/s
# global step 20, epoch: 3, batch: 6, loss: 5718.96582, valid score: 0.13500, speed: 7.08 step/s
# global step 21, epoch: 3, batch: 7, loss: 5310.51660, valid score: 0.14816, speed: 8.82 step/s
# global step 22, epoch: 4, batch: 1, loss: 5538.69629, valid score: 0.16323, speed: 8.17 step/s
# global step 23, epoch: 4, batch: 2, loss: 5479.57178, valid score: 0.17976, speed: 7.72 step/s
# global step 24, epoch: 4, batch: 3, loss: 5249.84375, valid score: 0.19750, speed: 8.08 step/s
# global step 25, epoch: 4, batch: 4, loss: 4972.58740, valid score: 0.21637, speed: 7.94 step/s
# global step 26, epoch: 4, batch: 5, loss: 5146.35107, valid score: 0.23645, speed: 8.09 step/s
# global step 27, epoch: 4, batch: 6, loss: 4756.84619, valid score: 0.25778, speed: 7.83 step/s
# global step 28, epoch: 4, batch: 7, loss: 4692.08398, valid score: 0.28040, speed: 8.88 step/s
# global step 29, epoch: 5, batch: 1, loss: 4558.50537, valid score: 0.30435, speed: 9.06 step/s
# global step 30, epoch: 5, batch: 2, loss: 4444.71143, valid score: 0.32960, speed: 7.40 step/s
# global step 31, epoch: 5, batch: 3, loss: 4509.17285, valid score: 0.35607, speed: 7.88 step/s
# global step 32, epoch: 5, batch: 4, loss: 4216.71436, valid score: 0.38363, speed: 7.87 step/s
# global step 33, epoch: 5, batch: 5, loss: 3922.33154, valid score: 0.41208, speed: 7.90 step/s
# global step 34, epoch: 5, batch: 6, loss: 4103.48926, valid score: 0.44116, speed: 8.32 step/s
# global step 35, epoch: 5, batch: 7, loss: 3786.03149, valid score: 0.47061, speed: 8.81 step/s
# global step 36, epoch: 6, batch: 1, loss: 3413.80127, valid score: 0.50008, speed: 9.40 step/s
# global step 37, epoch: 6, batch: 2, loss: 3399.29053, valid score: 0.52908, speed: 7.95 step/s
# global step 38, epoch: 6, batch: 3, loss: 3338.10132, valid score: 0.55705, speed: 8.08 step/s
# global step 39, epoch: 6, batch: 4, loss: 3163.07251, valid score: 0.58301, speed: 7.84 step/s
# global step 40, epoch: 6, batch: 5, loss: 3093.62451, valid score: 0.60534, speed: 7.21 step/s
# global step 41, epoch: 6, batch: 6, loss: 2836.62305, valid score: 0.62162, speed: 7.15 step/s
# global step 42, epoch: 6, batch: 7, loss: 2574.54248, valid score: 0.63004, speed: 8.95 step/s
# global step 43, epoch: 7, batch: 1, loss: 2620.79175, valid score: 0.63298, speed: 8.76 step/s
# global step 44, epoch: 7, batch: 2, loss: 2390.52588, valid score: 0.63988, speed: 8.05 step/s
# global step 45, epoch: 7, batch: 3, loss: 2236.04980, valid score: 0.64889, speed: 8.09 step/s
# global step 46, epoch: 7, batch: 4, loss: 2002.72241, valid score: 0.66426, speed: 8.00 step/s
# global step 47, epoch: 7, batch: 5, loss: 1948.04431, valid score: 0.67779, speed: 8.15 step/s
# global step 48, epoch: 7, batch: 6, loss: 1866.98096, valid score: 0.68543, speed: 8.16 step/s
# global step 49, epoch: 7, batch: 7, loss: 2018.09851, valid score: 0.68668, speed: 8.88 step/s
# global step 50, epoch: 8, batch: 1, loss: 1597.49902, valid score: 0.68380, speed: 13.60 step/s
# global step 51, epoch: 8, batch: 2, loss: 1686.54333, valid score: 0.68065, speed: 10.14 step/s
# global step 52, epoch: 8, batch: 3, loss: 1699.41675, valid score: 0.67973, speed: 10.32 step/s
# global step 53, epoch: 8, batch: 4, loss: 1576.99438, valid score: 0.68174, speed: 10.60 step/s
# global step 54, epoch: 8, batch: 5, loss: 1644.46753, valid score: 0.68603, speed: 10.59 step/s
# global step 55, epoch: 8, batch: 6, loss: 1550.31226, valid score: 0.69049, speed: 7.94 step/s
# global step 56, epoch: 8, batch: 7, loss: 1543.64856, valid score: 0.69276, speed: 8.89 step/s
# global step 57, epoch: 9, batch: 1, loss: 1517.57239, valid score: 0.69162, speed: 13.84 step/s
# global step 58, epoch: 9, batch: 2, loss: 1533.66492, valid score: 0.68983, speed: 10.39 step/s
# global step 59, epoch: 9, batch: 3, loss: 1533.29846, valid score: 0.69139, speed: 10.51 step/s
# global step 60, epoch: 9, batch: 4, loss: 1575.91968, valid score: 0.69523, speed: 8.03 step/s
# global step 61, epoch: 9, batch: 5, loss: 1619.42126, valid score: 0.69728, speed: 8.02 step/s
# global step 62, epoch: 9, batch: 6, loss: 1641.68689, valid score: 0.69623, speed: 10.79 step/s
# global step 63, epoch: 9, batch: 7, loss: 1640.73596, valid score: 0.69414, speed: 11.87 step/s
# global step 64, epoch: 10, batch: 1, loss: 1575.03552, valid score: 0.69381, speed: 13.07 step/s
# global step 65, epoch: 10, batch: 2, loss: 1570.74365, valid score: 0.69663, speed: 10.33 step/s
# global step 66, epoch: 10, batch: 3, loss: 1627.47852, valid score: 0.70192, speed: 8.17 step/s
# global step 67, epoch: 10, batch: 4, loss: 1589.06580, valid score: 0.70804, speed: 8.42 step/s
# global step 68, epoch: 10, batch: 5, loss: 1589.75586, valid score: 0.71319, speed: 8.22 step/s
# global step 69, epoch: 10, batch: 6, loss: 1540.40015, valid score: 0.71677, speed: 8.19 step/s
# global step 70, epoch: 10, batch: 7, loss: 1549.37683, valid score: 0.71960, speed: 9.17 step/s
# global step 71, epoch: 11, batch: 1, loss: 1574.11072, valid score: 0.72255, speed: 10.16 step/s
# global step 72, epoch: 11, batch: 2, loss: 1533.31689, valid score: 0.72529, speed: 8.40 step/s
# global step 73, epoch: 11, batch: 3, loss: 1488.56714, valid score: 0.72701, speed: 8.21 step/s
# global step 74, epoch: 11, batch: 4, loss: 1535.01990, valid score: 0.72750, speed: 7.52 step/s
# global step 75, epoch: 11, batch: 5, loss: 1515.89221, valid score: 0.72734, speed: 11.04 step/s
# ...
# global step 78, epoch: 10, batch: 6, loss: 1540.49377, valid score: 0.74093, speed: 7.42 step/s
# global step 79, epoch: 10, batch: 7, loss: 1542.63257, valid score: 0.74163, speed: 7.85 step/s
# global step 80, epoch: 10, batch: 8, loss: 1627.34094, valid score: 0.74159, speed: 12.96 step/s
# global step 81, epoch: 11, batch: 1, loss: 1576.13806, valid score: 0.74109, speed: 15.16 step/s
# global step 82, epoch: 11, batch: 2, loss: 1571.61780, valid score: 0.74035, speed: 10.28 step/s
# global step 83, epoch: 11, batch: 3, loss: 1538.15955, valid score: 0.73942, speed: 10.31 step/s
# global step 84, epoch: 11, batch: 4, loss: 1613.54724, valid score: 0.73827, speed: 10.28 step/s
# global step 85, epoch: 11, batch: 5, loss: 1527.26941, valid score: 0.73685, speed: 10.40 step/s
# global step 86, epoch: 11, batch: 6, loss: 1579.07080, valid score: 0.73555, speed: 10.29 step/s
# global step 87, epoch: 11, batch: 7, loss: 1528.71716, valid score: 0.73445, speed: 10.33 step/s
# global step 88, epoch: 11, batch: 8, loss: 1460.17590, valid score: 0.73367, speed: 12.72 step/s
# global step 89, epoch: 12, batch: 1, loss: 1548.61218, valid score: 0.73314, speed: 14.63 step/s
# global step 90, epoch: 12, batch: 2, loss: 1577.04382, valid score: 0.73272, speed: 10.11 step/s
# global step 91, epoch: 12, batch: 3, loss: 1569.10486, valid score: 0.73232, speed: 10.06 step/s
# global step 92, epoch: 12, batch: 4, loss: 1441.42627, valid score: 0.73190, speed: 10.28 step/s
# global step 93, epoch: 12, batch: 5, loss: 1568.24048, valid score: 0.73158, speed: 10.17 step/s
# global step 94, epoch: 12, batch: 6, loss: 1618.65198, valid score: 0.73134, speed: 10.28 step/s
# global step 95, epoch: 12, batch: 7, loss: 1530.64600, valid score: 0.73104, speed: 10.31 step/s
# global step 96, epoch: 12, batch: 8, loss: 1655.59058, valid score: 0.73075, speed: 12.57 step/s
# global step 97, epoch: 13, batch: 1, loss: 1546.69971, valid score: 0.73037, speed: 14.97 step/s
# global step 98, epoch: 13, batch: 2, loss: 1579.90112, valid score: 0.73007, speed: 10.23 step/s
# global step 99, epoch: 13, batch: 3, loss: 1534.48096, valid score: 0.72997, speed: 10.40 step/s
# global step 100, epoch: 13, batch: 4, loss: 1533.86829, valid score: 0.73007, speed: 10.34 step/s
# global step 101, epoch: 13, batch: 5, loss: 1523.23901, valid score: 0.73037, speed: 10.21 step/s
# global step 102, epoch: 13, batch: 6, loss: 1627.44238, valid score: 0.73077, speed: 10.44 step/s
# global step 103, epoch: 13, batch: 7, loss: 1474.85547, valid score: 0.73106, speed: 10.12 step/s
# global step 104, epoch: 13, batch: 8, loss: 1660.63135, valid score: 0.73141, speed: 12.31 step/s
# global step 105, epoch: 14, batch: 1, loss: 1548.51147, valid score: 0.73153, speed: 14.86 step/s
# global step 106, epoch: 14, batch: 2, loss: 1596.26343, valid score: 0.73165, speed: 10.24 step/s
# global step 107, epoch: 14, batch: 3, loss: 1537.06909, valid score: 0.73174, speed: 10.25 step/s
# global step 108, epoch: 14, batch: 4, loss: 1565.40601, valid score: 0.73200, speed: 10.22 step/s
# global step 109, epoch: 14, batch: 5, loss: 1538.94446, valid score: 0.73231, speed: 10.24 step/s
# global step 110, epoch: 14, batch: 6, loss: 1515.95996, valid score: 0.73271, speed: 10.22 step/s
# global step 111, epoch: 14, batch: 7, loss: 1520.40564, valid score: 0.73319, speed: 10.32 step/s
# global step 112, epoch: 14, batch: 8, loss: 1513.08667, valid score: 0.73378, speed: 12.57 step/s
# global step 113, epoch: 15, batch: 1, loss: 1510.82520, valid score: 0.73438, speed: 14.96 step/s
# global step 114, epoch: 15, batch: 2, loss: 1534.76550, valid score: 0.73494, speed: 10.17 step/s
# global step 115, epoch: 15, batch: 3, loss: 1574.39941, valid score: 0.73539, speed: 10.26 step/s
# global step 116, epoch: 15, batch: 4, loss: 1527.67920, valid score: 0.73581, speed: 10.15 step/s
# global step 117, epoch: 15, batch: 5, loss: 1552.26001, valid score: 0.73617, speed: 10.19 step/s
# global step 118, epoch: 15, batch: 6, loss: 1610.22314, valid score: 0.73649, speed: 10.17 step/s
# global step 119, epoch: 15, batch: 7, loss: 1514.79041, valid score: 0.73669, speed: 10.35 step/s
# global step 120, epoch: 15, batch: 8, loss: 1597.04407, valid score: 0.73679, speed: 12.54 step/s
# global step 121, epoch: 16, batch: 1, loss: 1623.38403, valid score: 0.73687, speed: 14.87 step/s
# global step 122, epoch: 16, batch: 2, loss: 1555.33545, valid score: 0.73680, speed: 10.16 step/s
# global step 123, epoch: 16, batch: 3, loss: 1558.42517, valid score: 0.73676, speed: 10.16 step/s
# global step 124, epoch: 16, batch: 4, loss: 1516.07239, valid score: 0.73669, speed: 10.31 step/s
# global step 125, epoch: 16, batch: 5, loss: 1550.27783, valid score: 0.73660, speed: 10.27 step/s
# global step 126, epoch: 16, batch: 6, loss: 1491.80310, valid score: 0.73646, speed: 10.32 step/s
# global step 127, epoch: 16, batch: 7, loss: 1521.24243, valid score: 0.73632, speed: 10.30 step/s
# global step 128, epoch: 16, batch: 8, loss: 1594.74927, valid score: 0.73628, speed: 12.79 step/s
# global step 129, epoch: 17, batch: 1, loss: 1517.37158, valid score: 0.73620, speed: 14.96 step/s
# global step 130, epoch: 17, batch: 2, loss: 1571.85132, valid score: 0.73609, speed: 10.28 step/s
# global step 131, epoch: 17, batch: 3, loss: 1487.04150, valid score: 0.73592, speed: 10.11 step/s
# global step 132, epoch: 17, batch: 4, loss: 1545.55542, valid score: 0.73589, speed: 10.30 step/s
# global step 133, epoch: 17, batch: 5, loss: 1563.55261, valid score: 0.73585, speed: 10.35 step/s
# global step 134, epoch: 17, batch: 6, loss: 1600.29944, valid score: 0.73584, speed: 10.24 step/s
# global step 135, epoch: 17, batch: 7, loss: 1508.55591, valid score: 0.73570, speed: 10.31 step/s
# global step 136, epoch: 17, batch: 8, loss: 1604.79236, valid score: 0.73566, speed: 12.73 step/s
# global step 137, epoch: 18, batch: 1, loss: 1497.24829, valid score: 0.73565, speed: 14.98 step/s
# global step 138, epoch: 18, batch: 2, loss: 1626.52393, valid score: 0.73567, speed: 10.21 step/s
# global step 139, epoch: 18, batch: 3, loss: 1510.81702, valid score: 0.73553, speed: 10.11 step/s
# global step 140, epoch: 18, batch: 4, loss: 1553.01123, valid score: 0.73545, speed: 10.15 step/s
# global step 141, epoch: 18, batch: 5, loss: 1583.17053, valid score: 0.73540, speed: 10.30 step/s
# global step 142, epoch: 18, batch: 6, loss: 1544.63403, valid score: 0.73529, speed: 10.39 step/s
# global step 143, epoch: 18, batch: 7, loss: 1508.61670, valid score: 0.73533, speed: 10.19 step/s
# global step 144, epoch: 18, batch: 8, loss: 1542.16003, valid score: 0.73539, speed: 12.30 step/s
# global step 145, epoch: 19, batch: 1, loss: 1484.52039, valid score: 0.73557, speed: 14.76 step/s
# global step 146, epoch: 19, batch: 2, loss: 1493.64404, valid score: 0.73580, speed: 10.02 step/s
# global step 147, epoch: 19, batch: 3, loss: 1612.97107, valid score: 0.73602, speed: 10.36 step/s
# global step 148, epoch: 19, batch: 4, loss: 1544.34290, valid score: 0.73615, speed: 10.38 step/s
# global step 149, epoch: 19, batch: 5, loss: 1555.55896, valid score: 0.73617, speed: 10.31 step/s
# global step 150, epoch: 19, batch: 6, loss: 1487.13330, valid score: 0.73621, speed: 10.31 step/s
# global step 151, epoch: 19, batch: 7, loss: 1594.35010, valid score: 0.73626, speed: 10.18 step/s
# global step 152, epoch: 19, batch: 8, loss: 1795.50439, valid score: 0.73633, speed: 12.44 step/s
# global step 153, epoch: 20, batch: 1, loss: 1516.10938, valid score: 0.73603, speed: 14.93 step/s
# global step 154, epoch: 20, batch: 2, loss: 1534.33496, valid score: 0.73581, speed: 10.20 step/s
# global step 155, epoch: 20, batch: 3, loss: 1584.14368, valid score: 0.73572, speed: 10.19 step/s
# global step 156, epoch: 20, batch: 4, loss: 1455.98853, valid score: 0.73555, speed: 10.20 step/s
# global step 157, epoch: 20, batch: 5, loss: 1530.52283, valid score: 0.73554, speed: 10.21 step/s
# global step 158, epoch: 20, batch: 6, loss: 1570.43640, valid score: 0.73568, speed: 10.05 step/s
# global step 159, epoch: 20, batch: 7, loss: 1616.61121, valid score: 0.73564, speed: 10.18 step/s
# global step 160, epoch: 20, batch: 8, loss: 1598.74377, valid score: 0.73560, speed: 12.34 step/s
# global step 161, epoch: 21, batch: 1, loss: 1523.65161, valid score: 0.73563, speed: 14.92 step/s
# global step 162, epoch: 21, batch: 2, loss: 1556.24060, valid score: 0.73583, speed: 10.22 step/s
# global step 163, epoch: 21, batch: 3, loss: 1571.79102, valid score: 0.73607, speed: 10.14 step/s
# global step 164, epoch: 21, batch: 4, loss: 1580.44104, valid score: 0.73627, speed: 10.20 step/s
# global step 165, epoch: 21, batch: 5, loss: 1542.04565, valid score: 0.73640, speed: 10.23 step/s
# global step 166, epoch: 21, batch: 6, loss: 1478.84998, valid score: 0.73650, speed: 10.30 step/s
# global step 167, epoch: 21, batch: 7, loss: 1558.65039, valid score: 0.73667, speed: 10.22 step/s
# global step 168, epoch: 21, batch: 8, loss: 1475.83228, valid score: 0.73685, speed: 12.52 step/s
# global step 169, epoch: 22, batch: 1, loss: 1563.24011, valid score: 0.73700, speed: 14.85 step/s
# global step 170, epoch: 22, batch: 2, loss: 1547.83862, valid score: 0.73718, speed: 10.11 step/s
# global step 171, epoch: 22, batch: 3, loss: 1505.22437, valid score: 0.73729, speed: 10.28 step/s
# global step 172, epoch: 22, batch: 4, loss: 1603.94897, valid score: 0.73739, speed: 10.22 step/s
# global step 173, epoch: 22, batch: 5, loss: 1593.87378, valid score: 0.73733, speed: 10.18 step/s
# global step 174, epoch: 22, batch: 6, loss: 1471.93433, valid score: 0.73721, speed: 10.19 step/s
# global step 175, epoch: 22, batch: 7, loss: 1539.54822, valid score: 0.73713, speed: 10.44 step/s
# global step 176, epoch: 22, batch: 8, loss: 1536.96826, valid score: 0.73710, speed: 12.64 step/s
# global step 177, epoch: 23, batch: 1, loss: 1516.57007, valid score: 0.73726, speed: 15.09 step/s
# global step 178, epoch: 23, batch: 2, loss: 1534.88843, valid score: 0.73736, speed: 10.28 step/s
# global step 179, epoch: 23, batch: 3, loss: 1547.74158, valid score: 0.73736, speed: 10.27 step/s
# global step 180, epoch: 23, batch: 4, loss: 1526.02466, valid score: 0.73738, speed: 10.34 step/s
# global step 181, epoch: 23, batch: 5, loss: 1610.83521, valid score: 0.73746, speed: 10.25 step/s
# global step 182, epoch: 23, batch: 6, loss: 1537.53479, valid score: 0.73745, speed: 10.34 step/s
# global step 183, epoch: 23, batch: 7, loss: 1541.98608, valid score: 0.73732, speed: 10.34 step/s
# global step 184, epoch: 23, batch: 8, loss: 1410.85632, valid score: 0.73707, speed: 12.85 step/s
# global step 185, epoch: 24, batch: 1, loss: 1504.46558, valid score: 0.73699, speed: 14.87 step/s
# global step 186, epoch: 24, batch: 2, loss: 1562.23474, valid score: 0.73707, speed: 10.15 step/s
# global step 187, epoch: 24, batch: 3, loss: 1514.30017, valid score: 0.73700, speed: 10.14 step/s
# global step 188, epoch: 24, batch: 4, loss: 1591.30884, valid score: 0.73689, speed: 10.27 step/s
# global step 189, epoch: 24, batch: 5, loss: 1575.52515, valid score: 0.73673, speed: 10.42 step/s
# global step 190, epoch: 24, batch: 6, loss: 1542.83789, valid score: 0.73655, speed: 10.35 step/s
# global step 191, epoch: 24, batch: 7, loss: 1513.84949, valid score: 0.73645, speed: 10.36 step/s
# global step 192, epoch: 24, batch: 8, loss: 1577.00696, valid score: 0.73646, speed: 12.71 step/s
# global step 193, epoch: 25, batch: 1, loss: 1479.37793, valid score: 0.73632, speed: 14.80 step/s
# global step 194, epoch: 25, batch: 2, loss: 1477.47729, valid score: 0.73641, speed: 10.34 step/s
# global step 195, epoch: 25, batch: 3, loss: 1632.52979, valid score: 0.73654, speed: 10.32 step/s
# global step 196, epoch: 25, batch: 4, loss: 1504.87061, valid score: 0.73663, speed: 10.38 step/s
# global step 197, epoch: 25, batch: 5, loss: 1585.99121, valid score: 0.73669, speed: 10.36 step/s
# global step 198, epoch: 25, batch: 6, loss: 1551.39697, valid score: 0.73656, speed: 10.35 step/s
# global step 199, epoch: 25, batch: 7, loss: 1557.08826, valid score: 0.73653, speed: 10.26 step/s
# global step 200, epoch: 25, batch: 8, loss: 1457.59607, valid score: 0.73649, speed: 12.49 step/s
# global step 201, epoch: 26, batch: 1, loss: 1501.11023, valid score: 0.73671, speed: 15.04 step/s
# global step 202, epoch: 26, batch: 2, loss: 1510.30359, valid score: 0.73690, speed: 10.19 step/s
# global step 203, epoch: 26, batch: 3, loss: 1524.64221, valid score: 0.73714, speed: 10.44 step/s
# global step 204, epoch: 26, batch: 4, loss: 1542.67542, valid score: 0.73726, speed: 10.32 step/s
# global step 205, epoch: 26, batch: 5, loss: 1571.77490, valid score: 0.73734, speed: 10.37 step/s
# global step 206, epoch: 26, batch: 6, loss: 1626.89355, valid score: 0.73741, speed: 10.21 step/s
# global step 207, epoch: 26, batch: 7, loss: 1528.51025, valid score: 0.73744, speed: 10.47 step/s
# global step 208, epoch: 26, batch: 8, loss: 1580.39197, valid score: 0.73747, speed: 12.73 step/s
# global step 209, epoch: 27, batch: 1, loss: 1526.84070, valid score: 0.73770, speed: 15.14 step/s
# global step 210, epoch: 27, batch: 2, loss: 1596.20300, valid score: 0.73788, speed: 10.38 step/s
# global step 211, epoch: 27, batch: 3, loss: 1515.84778, valid score: 0.73788, speed: 10.32 step/s
# global step 212, epoch: 27, batch: 4, loss: 1559.41223, valid score: 0.73784, speed: 10.40 step/s
# global step 213, epoch: 27, batch: 5, loss: 1522.73816, valid score: 0.73763, speed: 10.38 step/s
# global step 214, epoch: 27, batch: 6, loss: 1576.35254, valid score: 0.73746, speed: 10.22 step/s
# global step 215, epoch: 27, batch: 7, loss: 1503.76294, valid score: 0.73736, speed: 10.35 step/s
# global step 216, epoch: 27, batch: 8, loss: 1509.43530, valid score: 0.73737, speed: 12.64 step/s
# global step 217, epoch: 28, batch: 1, loss: 1554.03381, valid score: 0.73746, speed: 15.12 step/s
# global step 218, epoch: 28, batch: 2, loss: 1562.77588, valid score: 0.73746, speed: 10.31 step/s
# global step 219, epoch: 28, batch: 3, loss: 1578.53528, valid score: 0.73743, speed: 10.30 step/s
# global step 220, epoch: 28, batch: 4, loss: 1483.34998, valid score: 0.73729, speed: 10.38 step/s
# global step 221, epoch: 28, batch: 5, loss: 1527.50244, valid score: 0.73721, speed: 10.56 step/s
# global step 222, epoch: 28, batch: 6, loss: 1535.37463, valid score: 0.73709, speed: 10.46 step/s
# global step 223, epoch: 28, batch: 7, loss: 1542.03259, valid score: 0.73697, speed: 10.33 step/s
# global step 224, epoch: 28, batch: 8, loss: 1540.49890, valid score: 0.73698, speed: 12.63 step/s
# global step 225, epoch: 29, batch: 1, loss: 1524.30884, valid score: 0.73691, speed: 14.92 step/s
# global step 226, epoch: 29, batch: 2, loss: 1577.63452, valid score: 0.73695, speed: 10.37 step/s
# global step 227, epoch: 29, batch: 3, loss: 1546.07507, valid score: 0.73686, speed: 10.31 step/s
# global step 228, epoch: 29, batch: 4, loss: 1511.03967, valid score: 0.73672, speed: 10.26 step/s
# global step 229, epoch: 29, batch: 5, loss: 1517.59778, valid score: 0.73660, speed: 10.21 step/s
# global step 230, epoch: 29, batch: 6, loss: 1571.47046, valid score: 0.73661, speed: 10.30 step/s
# global step 231, epoch: 29, batch: 7, loss: 1560.04272, valid score: 0.73664, speed: 10.44 step/s
# global step 232, epoch: 29, batch: 8, loss: 1467.75671, valid score: 0.73681, speed: 12.80 step/s
# global step 233, epoch: 30, batch: 1, loss: 1483.07153, valid score: 0.73703, speed: 15.06 step/s
# global step 234, epoch: 30, batch: 2, loss: 1526.91931, valid score: 0.73721, speed: 10.24 step/s
# global step 235, epoch: 30, batch: 3, loss: 1521.63953, valid score: 0.73733, speed: 10.23 step/s
# global step 236, epoch: 30, batch: 4, loss: 1652.68823, valid score: 0.73753, speed: 10.34 step/s
# global step 237, epoch: 30, batch: 5, loss: 1538.38049, valid score: 0.73749, speed: 10.31 step/s
# global step 238, epoch: 30, batch: 6, loss: 1575.75720, valid score: 0.73748, speed: 10.33 step/s
# global step 239, epoch: 30, batch: 7, loss: 1494.54199, valid score: 0.73736, speed: 10.37 step/s
# global step 240, epoch: 30, batch: 8, loss: 1510.21948, valid score: 0.73746, speed: 12.66 step/s

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, data_x, index, data_y):
        self.data_x = data_x
        self.index = index
        self.data_y = data_y

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        x = self.data_x[self.index[idx]]
        y = self.data_y[self.index[idx]]
        return x, y

def create_dataloader(data_x, index, batch_size, data_y=None, shuffle=True):
    data = [{
        'data': data_x[i], 
        'label': 0 if data_y is None else data_y[i]} 
        for i in index]
    dataset = CustomDataset(data_x, index, [data[0]['label']])
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)
    return dataloader

# %%
# predict the data
pred_1 = do_pred(test_x_1, 'm1')
pred_2 = do_pred(test_x_2, 'm2')
pred_3 = do_pred(test_x_3, 'm3')
# Out:
# ------
# predict ... m1
# predict x: (168, 9)
# predict kfold... 0
# predict kfold... 1
# predict kfold... 2
# predict kfold... 3
# predict kfold... 4
# ------
# predict ... m2
# predict x: (168, 9)
# predict kfold... 0
# predict kfold... 1
# predict kfold... 2
# predict kfold... 3
# predict kfold... 4
# ------
# predict ... m3
# predict x: (168, 9)
# predict kfold... 0
# predict kfold... 1
# predict kfold... 2
# predict kfold... 3
# predict kfold... 4

# %%
pred_1

# %%
pred_2
# Out:
# [array([[[ 5.7126174 , 11.432822  ,  0.74037045,  2.012467  ,
#            0.1133861 ,  2.83134   ],
#          [ 7.512301  , 15.097921  ,  0.9574025 ,  2.6407466 ,
#            0.13524534,  3.7198822 ],
#          [ 5.7220187 , 11.4822855 ,  0.7426857 ,  2.015801  ,
#            0.11239999,  2.847542  ],
#          ...,
#          [12.260164  , 24.71205   ,  1.539854  ,  4.317631  ,
#            0.1793435 ,  6.0706224 ],
#          [15.031891  , 30.293568  ,  1.8744619 ,  5.289918  ,
#            0.22183798,  7.427077  ],
#          [ 8.806782  , 17.700756  ,  1.1224313 ,  3.1013658 ,
#            0.15126386,  4.3564687 ]]], dtype=float32),
#  array([[[ 8.67934   , 17.02969   ,  1.1043988 ,  3.0831711 ,
#            0.12959509,  4.272644  ],
#          [ 9.806995  , 19.239462  ,  1.2361174 ,  3.4675603 ,
#            0.13783985,  4.82109   ],
#          [ 8.548341  , 16.771044  ,  1.0922241 ,  3.0246313 ,
#            0.12258688,  4.208567  ],
#          ...,
#          [17.577496  , 34.469547  ,  2.1572995 ,  6.2058973 ,
#            0.23360933,  8.602524  ],
#          [16.112663  , 31.614449  ,  1.990802  ,  5.6846094 ,
#            0.21864754,  7.8884325 ],
#          [ 9.482496  , 18.604027  ,  1.1988169 ,  3.3500955 ,
#            0.13918898,  4.6587534 ]]], dtype=float32),
#  array([[[10.420502  , 20.759905  ,  1.3011098 ,  3.7068677 ,
#            0.11885174,  5.52882   ],
#          [12.325871  , 24.568556  ,  1.530786  ,  4.3725014 ,
#            0.14167738,  6.5314403 ],
#          [12.126117  , 24.16761   ,  1.5041246 ,  4.29451   ,
#            0.13571501,  6.434222  ],
#          ...,
#          [18.511732  , 36.916424  ,  2.2735837 ,  6.539938  ,
#            0.21825385,  9.802678  ],
#          [12.133239  , 24.17494   ,  1.5039392 ,  4.3050847 ,
#            0.14766276,  6.4234285 ],
#          [ 7.2151856 , 14.33596   ,  0.91328746,  2.578371  ,
#            0.08391752,  3.8304186 ]]], dtype=float32),
#  array([[[ 6.508052  , 12.948695  ,  0.6195738 ,  2.0067701 ,
#            0.14654408,  2.9915824 ],
#          [ 6.7995033 , 13.527048  ,  0.6488788 ,  2.0897727 ,
#            0.14574386,  3.1261904 ],
#          [13.448272  , 26.842186  ,  1.2684233 ,  4.137137  ,
#            0.22367163,  6.1658187 ],
#          ...,
#          [13.044622  , 26.054935  ,  1.2277126 ,  4.021499  ,
#            0.21919264,  5.9844513 ],
#          [13.367358  , 26.679401  ,  1.2507564 ,  4.1070843 ,
#            0.21503936,  6.1276693 ],
#          [ 9.732795  , 19.414083  ,  0.92316025,  2.9986005 ,
#            0.17561547,  4.4627266 ]]], dtype=float32),
#  array([[[ 7.346867  , 15.569487  ,  0.754278  ,  2.4676795 ,
#            0.13926509,  3.896253  ],
#          [ 6.9398813 , 14.721856  ,  0.70863575,  2.3372288 ,
#            0.13703531,  3.6767306 ],
#          [ 6.044305  , 12.817097  ,  0.6124457 ,  2.0357978 ,
#            0.12433127,  3.2034757 ],
#          ...,
#          [15.225564  , 32.3085    ,  1.5571398 ,  5.1215754 ,
#            0.22622466,  8.105605  ],
#          [14.279746  , 30.280102  ,  1.456679  ,  4.802293  ,
#            0.22548226,  7.6010137 ],
#          [ 5.8790393 , 12.487966  ,  0.60778606,  1.9724761 ,
#            0.11835702,  3.1193788 ]]], dtype=float32)]

# %%
pred_3
# Out:
# [array([[[ 7.2866135 , 14.600386  ,  0.9471701 ,  2.586327  ,
#            0.1274373 ,  3.6428785 ],
#          [ 9.54134   , 19.182636  ,  1.2247956 ,  3.3812757 ,
#            0.1540589 ,  4.766201  ],
#          [ 7.1971927 , 14.450498  ,  0.93819463,  2.5538664 ,
#            0.12619999,  3.6092045 ],
#          ...,
#          [11.033541  , 22.209675  ,  1.411948  ,  3.917984  ,
#            0.16225484,  5.52308   ],
#          [13.393649  , 26.952156  ,  1.7012949 ,  4.7516913 ,
#            0.19811055,  6.6881866 ],
#          [ 9.680764  , 19.448484  ,  1.2498126 ,  3.4359608 ,
#            0.1581724 ,  4.834304  ]]], dtype=float32),
#  array([[[11.982237  , 23.59045   ,  1.3857777 ,  3.7512968 ,
#            0.11408469,  5.598055  ],
#          [11.994546  , 23.607393  ,  1.3816817 ,  3.750216  ,
#            0.11051969,  5.6097593 ],
#          [14.546179  , 28.645458  ,  1.6695065 ,  4.547466  ,
#            0.13951106,  6.801162  ],
#          ...,
#          [18.129778  , 35.708668  ,  2.072081  ,  5.6653743 ,
#            0.17884088,  8.474524  ],
#          [11.640337  , 22.927309  ,  1.3370819 ,  3.6400573 ,
#            0.10219786,  5.4413624 ],
#          [ 8.455549  , 16.639841  ,  0.9713296 ,  2.6482368 ,
#            0.06613747,  3.9480076 ]]], dtype=float32),
#  array([[[ 9.917761  , 20.091974  ,  1.2812172 ,  3.5225935 ,
#            0.15205498,  5.0081916 ],
#          [ 9.655087  , 19.541994  ,  1.2441206 ,  3.4370174 ,
#            0.14650626,  4.875744  ],
#          [11.644546  , 23.600767  ,  1.4948719 ,  4.1308775 ,
#            0.16946144,  5.8794527 ],
#          ...,
#          [19.160984  , 38.7828    ,  2.43911   ,  6.7702465 ,
#            0.25379342,  9.695375  ],
#          [14.484093  , 29.333385  ,  1.8520005 ,  5.1247587 ,
#            0.201055  ,  7.321912  ],
#          [ 7.736467  , 15.67051   ,  1.0051858 ,  2.7514596 ,
#            0.11803157,  3.903692  ]]], dtype=float32),
#  array([[[ 9.7101145 , 19.372707  ,  0.9793339 ,  3.311638  ,
#            0.15435782,  4.7538867 ],
#          [ 9.343527  , 18.653011  ,  0.9498827 ,  3.185267  ,
#            0.14645836,  4.5941586 ],
#          [13.321113  , 26.57768   ,  1.3454899 ,  4.5459433 ,
#            0.20100585,  6.5088277 ],
#          ...,
#          [12.816651  , 25.548813  ,  1.2927427 ,  4.374457  ,
#            0.19642773,  6.267403  ],
#          [12.107082  , 24.127022  ,  1.2212056 ,  4.1364    ,
#            0.18719712,  5.9217424 ],
#          [ 9.6218605 , 19.1967    ,  0.9764042 ,  3.2817564 ,
#            0.15371975,  4.7264442 ]]], dtype=float32),
#  array([[[ 9.329941  , 19.232649  ,  1.023772  ,  3.1633296 ,
#            0.10866734,  4.8187847 ],
#          [11.516735  , 23.761955  ,  1.2470925 ,  3.9008725 ,
#            0.12536186,  5.9601064 ],
#          [ 9.968445  , 20.549223  ,  1.0896685 ,  3.376498  ,
#            0.10339087,  5.158286  ],
#          ...,
#          [16.34329   , 33.740334  ,  1.7640499 ,  5.540184  ,
#            0.18364063,  8.477635  ],
#          [14.009436  , 28.908598  ,  1.514894  ,  4.7500362 ,
#            0.15933973,  7.261619  ],
#          [ 9.157825  , 18.88171   ,  1.0028943 ,  3.1030707 ,
#            0.10172567,  4.7333775 ]]], dtype=float32)]

# %%
result = np.vstack((
    np.mean(pred_1, axis=0).squeeze(),
    np.mean(pred_2, axis=0).squeeze(),
    np.mean(pred_3, axis=0).squeeze()))

result[result<0] = 0
result = pd.concat([df_sub2['time'], pd.DataFrame(result)], axis=1)
result.columns = df_sub2.columns
result.to_csv('/content/sample_data/result_0929_1.csv', index=False, encoding='utf-8')
result
# Out:
#                  time      PM2.5       PM10       SO2       NO2        CO  \
# 0    2020-05-01 01:00  12.544618  25.014267  1.424340  4.664826  0.192623
# 1    2020-05-01 02:00  13.804285  27.509327  1.566731  5.134905  0.206922
# 2    2020-05-01 03:00  13.611275  27.106724  1.523612  5.000238  0.201798
# 3    2020-05-01 04:00  14.629138  29.265095  1.663809  5.417943  0.217221
# 4    2020-05-01 05:00  12.811696  25.552176  1.460434  4.723420  0.191951
# ..                ...        ...        ...       ...       ...       ...
# 499  2020-07-07 20:00  14.988207  30.180338  1.745675  5.104405  0.188626
# 500  2020-07-07 21:00  13.750424  27.757803  1.608932  4.705729  0.176000
# 501  2020-07-07 22:00  15.496849  31.198059  1.795986  5.253649  0.194991
# 502  2020-07-07 23:00  13.126920  26.449692  1.525295  4.480589  0.169580
# 503  2020-07-08 00:00   8.930494  17.967449  1.041125  3.044097  0.119557
#
#            O3
# 0    6.490225
# 1    7.134004
# 2    6.969096
# 3    7.560815
# 4    6.567334
# ..        ...
# 499  7.432242
# 500  6.858172
# 501  7.687603
# 502  6.526965
# 503  4.429165
#
# [504 rows x 7 columns]

# %%
result.to_csv('/content/drive/MyDrive/Data Science/prediction_0929_1.csv', index=False, encoding='utf-8')

# %%
from google.colab import drive
drive.mount('/content/drive')
